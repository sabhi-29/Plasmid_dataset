# %% [markdown]
# <a href="https://colab.research.google.com/github/sabhi-29/Plasmid_dataset/blob/main/Plasmid_data_version_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing biopython first
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.23.5)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
# Importing neccesary libraries
import os
import numpy as np
import pandas as pd
from Bio import Entrez, SeqIO
from urllib.request import urlretrieve
import requests

# %%
# Making function to create folders to store plasmid details for various hits
# separately
def create_new_folder(folder_name):
    # Check if the folder already exists
    if not os.path.exists(folder_name):
        # Create the folder

        try:
          os.mkdir(folder_name)
          return os.path.abspath(folder_name)
        except:
          if not os.path.exists("weird_name"):
            folder_name = "weird_name"
            os.mkdir(folder_name)
            return os.path.abspath(folder_name)
          else:
            print(f"Folder weird_name already exists.")
            return None
    else:
        print(f"Folder '{folder_name}' already exists.")
        return None

# Example usage
# folder_name = "new_folder"
# folder_path = create_new_folder(folder_name)
# if folder_path:
#     print(f"Folder '{folder_name}' created at {folder_path}")

# %%
# Writing the function that will pull all the plasmid hits
def plasmid_data(plasmid_name_1, plasmid_email_id):

  # Making the folder for the plamsmid hits and storing it's path
  folder_name = plasmid_name_1
  if '.' in folder_name:
    folder_name = folder_name.split('.')
    temp_str = ''
    for sub_str in folder_name:
      temp_str += sub_str
    folder_name = temp_str
  path = create_new_folder(folder_name)
  print(f"Folder made for {folder_name}")

  # Setting up our query and accessing Entrez
  query = f"Plasmid {plasmid_name_1}"
  email = plasmid_email_id
  Entrez.email = email

  # Searching GenBank now
  handle = Entrez.esearch(db = 'nucleotide', term = query, retmax = 100)
  record_id = Entrez.read(handle)['IdList']
  handle.close()
  # print(record_id)
  # Now storing the data we got in form of a dataframe
  # First making the dictionary to store the data

  plasmid_data = {"Accession No.": [], 'Organism': [], 'Topology': [], 'Plasmid': [], 'Nucleotide Sequence': [],
                  'Locus Tag': [], 'Gene Location': [], 'Gene Product': [], 'Gene Sequence': []}

  # Going through each record we got from the entrez esearch
  for records in record_id:

    # Extracting the genbank record for the id
    genbank_record = Entrez.efetch(db = 'nucleotide', id = records, rettype = 'gb', retmode = 'text')
    # Reading the record
    gb_record = SeqIO.read(genbank_record, 'genbank')
    if (len(gb_record.id) != 0 and len(gb_record.description) != 0) and len(gb_record.seq) != 0:
      # We will first check if the sequence is of our plasmid of interest and complete or not, if yes then we proceed
      # Extracting Accession Number and description
      accession = [str(gb_record.annotations['accessions'][0])]
      description = gb_record.description

      ##### DEBUGGING PRINT STATEMENT ##############################
      print(f"Current hit: {plasmid_name_1} :- {description}")
      ################################################################


      # We are going to add the record only if it is complete and has the plasmid of interest
      if plasmid_name_1.lower() in description.lower() and 'complete sequence' in description.lower():
        organism = [str(gb_record.annotations["source"])]
        plasmid_name = [str(description.split("plasmid ")[-1].split(",")[0])]
        locus_tag = []
        topology = [str(gb_record.annotations['topology'])]
        gene_prdt = []
        gene_seq = []
        location = []

        ###########################################
        # Getting nucleotide sequence
        handle = Entrez.efetch(db="nucleotide", id=accession[0], rettype="fasta", retmode="text")
        fasta_sequence = handle.read()
        handle.close()
        fasta_seq_split = [x for x in fasta_sequence.split()[1:] if len(x) > 10] # To remove all the words before the sequence (get fasta file first then proceed)
        nuc_seq = ''
        for i in range(len(fasta_seq_split)):
          nuc_seq += fasta_seq_split[i]
        # print(nuc_seq)
        nucleotide_seq = [str(nuc_seq)]
        ###########################################################

        # Now we will access the record and store the bacteria name, accession number,
        # topology, plasmid, nucleotide sequence, locus tags for each gene present in it and thier sequence

        # Now that we have nucleotide of interest we can add it in the dataset
        for features in gb_record.features:
          if features.type == 'CDS':
            # In case translation, locus tag, gene product is missing then we simply leave that cell empty
            # print(features.qualifiers.keys())
            if 'locus_tag' in features.qualifiers.keys():
              locus_tag.append(str(features.qualifiers.get('locus_tag')[0]))
            else:
              locus_tag.append('NaN')
            if 'product' in features.qualifiers.keys():
              gene_prdt.append(str(features.qualifiers['product'][0]))
            else:
              gene_prdt.append('NaN')
            if 'translation' in features.qualifiers.keys():
              gene_seq.append(str(features.qualifiers['translation'][0]))
            else:
              gene_seq.append('NaN')
          if features.type == 'gene':
            location.append(str(features.location))

        # We will make the dataframe and store it only if all the columns are of the same length
        # print(len(locus_tag), len(locus_tag))
        if (len(locus_tag) == len(location) and len(locus_tag)!= 0):
          plasmid_data["Accession No."] = accession*len(locus_tag)
          plasmid_data["Organism"] = organism*len(locus_tag)
          plasmid_data["Topology"] = topology*len(locus_tag)
          plasmid_data["Plasmid"] = plasmid_name*len(locus_tag)
          plasmid_data["Nucleotide Sequence"] = nucleotide_seq*len(locus_tag)
          plasmid_data["Locus Tag"] = locus_tag
          plasmid_data["Gene Length"] = [len(x) for x in gene_seq]
          plasmid_data["Gene Sequence"] = gene_seq
          plasmid_data["Gene Product"] = gene_prdt
          plasmid_data['Gene Location'] = location
          # print(plasmid_data)
          # Making the dataframe
          dataframe = pd.DataFrame(plasmid_data)
          # Saving the dataframe
          dataframe.to_excel(f'{path}/{accession[0]}_{plasmid_name[0]}_data.xlsx', index = False)
          print(f"DataFrame made for {plasmid_name[0]} at {path}/{accession[0]}")
          dataframe.head()
        else:
          print("The dataset does not contain all the values")

# %%
# # Downloading the list of plasmids in PLSDB Database

# url = 'https://github.com/sabhi-29/Plasmid_dataset/blob/4fd1d870cffd9c364a183e7dacf7508b9f962e8c/plsdb.xlsx'
# r = requests.get(url, allow_redirects=True)
# open(f'plsdb.xlsx', 'wb').write(r.content)

# %%
# Reading the file into dataframe
plsdb_excel =  '/content/drive/MyDrive/plsdb_acc_num_data.xlsx'
df_plsdb = pd.read_excel(plsdb_excel, header=0, index_col=False, keep_default_na=True)

# Extracting the description list
descriptions = [x.split() for x in df_plsdb['Description_NUCCORE']]

# %%
plasmids = []

for splits in descriptions:
  try:
    plasmids.append(splits[splits.index('plasmid')+1])
  except:
    continue
# print(len(plasmids))

# %%
#### JUST TO SHOW THE OUTPUT OF THE ABOVE

plasmids = []

for splits in descriptions:
  try:
    plasmids.append(splits[splits.index('plasmid')+1])
  except:
    continue
# Out:
# Streaming output truncated to the last 5000 lines.
# lpG27,
# lpV47,
# lpT28,
# lpN31,
# lpE27,
# lpB58,
# cp28,
# megaplasmid,
# CtrF-6068_plasmid,
# CtrE-32931_plasmid,
# pIEC338SC3,
# pIEC338SC2,
# pIEC338SCOX,
# pSHB9,
# plasmid4
# plasmid3
# plasmid2
# plasmid1
# QpH1,
# unnamed2,
# unnamed1,
# Plasmid3
# Plasmid2
# Plasmid1
# pFRP1-2,
# pFRP1-1,
# pLS1-1,
# 3,
# 2,
# 1,
# pD36-4,
# pD36-3,
# pRAY*
# pD36-1,
# 2,
# 1,
# pTA78,
# pTA69,
# pTA16,
# pTA14,
# ABSP7_p5,
# ABSP7_p4,
# ABSP7_p3,
# ABSP7_p2,
# ABSP7_p1,
# plasmid200,
# plasmid100,
# pFORC13,
# pXAC33,
# pXAC64,
# lbp2,
# lbp1,
# pFORC4,
# bpln_1p,
# skipping ['Sphingopyxis', 'macrogoltabida', 'strain', '203', 'plasmid,', 'complete', 'sequence']
# skipping ['Sphingopyxis', 'macrogoltabida', 'strain', '203', 'plasmid,', 'complete', 'sequence']
# B,
# A,
# pNS6003,
# pNS6002,
# pNS6001,
# pTrp,
# pLeu,
# skipping ['Bacillus', 'clausii', 'strain', 'ENTPro', 'plasmid,', 'complete', 'sequence']
# skipping ['Altererythrobacter', 'atlanticus', 'strain', '26DY36', 'plasmid,', 'complete', 'sequence']
# skipping ['Candidatus', 'Profftella', 'armatura', 'strain', 'YCPA', 'plasmid,', 'complete', 'sequence']
# plasmid-37,
# plasmid-32,
# plasmid-35-36,
# pCdes2,
# pCdes1,
# pCDU1,
# pCCO1,
# pCUNV1,
# pCO-6,
# unnamed
# unnamed
# unnamed
# unnamed
# skipping ['Candidatus', 'Baumannia', 'cicadellinicola', 'strain', 'B-GSS', 'plasmid,', 'complete', 'sequence']
# OSB_p1,
# pLIMHP1,
# pMaD11,
# pMaD10,
# pMaD9,
# pMaD8,
# pMaD6,
# pMaD5,
# pMaD4,
# pMaD2,
# pMaD1,
# skipping ['Xanthomonas', 'oryzae', 'pv.', 'oryzicola', 'strain', 'CFBP2286', 'plasmid,', 'complete', 'sequence']
# XBC_p,
# skipping ['Xenorhabdus', 'bovienii', 'str.', 'CS03', 'megaplasmid,', 'complete', 'genome']
# skipping ['Burkholderia', 'thailandensis', '34', 'plasmid,', 'complete', 'sequence']
# pBTU,
# lcp3,
# lcp2,
# lcp1,
# :
# :
# unnamed1,
# unnamed2,
# wkB8_plasmid,
# pLOOC260-2
# pLOOC260-1
# pACA1.2,
# pACA1.1,
# megaplasmid
# skipping ['Thalassospira', 'xiamenensis', 'M-5', '=', 'DSM', '17429', 'plasmid,', 'complete', 'genome']
# p12124569,
# plc,
# plb,
# pla,
# pPstS2
# pPstS1
# p5,
# p2,
# p6,
# p4,
# p3,
# p1,
# 1
# skipping ['Xylella', 'fastidiosa', 'subsp.', 'fastidiosa', 'GB514', 'plasmid,', 'complete', 'sequence']
# skipping ['Xanthomonas', 'albilineans', 'str.', 'GPE', 'PC73,', 'plasmid,', 'complete', 'genome']
# skipping ['Xanthomonas', 'albilineans', 'str.', 'GPE', 'PC73,', 'plasmid,', 'complete', 'genome']
# skipping ['Xanthomonas', 'albilineans', 'str.', 'GPE', 'PC73,', 'plasmid,', 'complete', 'genome']
# skipping ['Lactobacillus', 'amylovorus', 'GRL', '1118', 'plasmid2,', 'complete', 'sequence']
# skipping ['Lactobacillus', 'amylovorus', 'GRL', '1118', 'plasmid1,', 'complete', 'sequence']
# Plasmid0001,
# pMT,
# pPCP,
# pCD,
# pAPA32-012
# pAPA26-013
# pAPA03-010
# pAPA12-014
# pLAtc2,
# pLAtc3,
# pLAtc1,
# skipping ['Acidithiobacillus', 'caldus', 'SM-1', 'megaplasmid,', 'complete', 'sequence']
# pAPA01-060
# pAPA01-050
# pAPA01-040
# pAPA01-030
# pAPA01-020
# pAPA01-011
# skipping ['Campylobacter', 'lari', 'RM2100', 'megaplasmid', 'pCL2100,', 'complete', 'sequence']
# pNGK,
# pET44827,
# plasmid_153kb,
# plasmid_59kb,
# 2,
# 1,
# skipping ['Nitrosomonas', 'eutropha', 'C91', 'Plasmid2,', 'complete', 'sequence']
# skipping ['Nitrosomonas', 'eutropha', 'C91', 'Plasmid1,', 'complete', 'sequence']
# skipping ['Ralstonia', 'eutropha', 'H16', 'megaplasmid', 'pHG1,', 'complete', 'sequence']
# NT26_p2,
# NT26_p1,
# pDSM4216,
# CACET_5p,
# skipping ['Clostridium', 'carboxidivorans', 'P7', 'plasmid,', 'complete', 'sequence']
# pCAV1151-296,
# pCAV1151-215,
# pCAV1151-83,
# pKPC_CAV1151,
# skipping ['Hoeflea', 'sp.', 'IMCC20628', 'plasmid,', 'complete', 'sequence']
# skipping ['Hoeflea', 'sp.', 'IMCC20628', 'plasmid,', 'complete', 'sequence']
# skipping ['Spongiibacter', 'sp.', 'IMCC21906', 'plasmid,', 'complete', 'sequence']
# skipping ['Sedimenticola', 'thiotaurini', 'strain', 'SIP-G1', 'plasmid,', 'complete', 'sequence']
# unnamed3,
# unnamed2,
# unnamed1,
# MGMAQ_p,
# unnamed2,
# unnamed1,
# pBII_1,
# pSMB1
# :
# pAG001,
# skipping ['Paenibacillus', 'sp.', 'IHBB', '10380', 'plasmid,', 'complete', 'sequence']
# 2,
# 1,
# skipping ['Hymenobacter', 'sp.', 'DG25B', 'plasmid,', 'complete', 'sequence']
# skipping ['Hymenobacter', 'sp.', 'DG25B', 'plasmid,', 'complete', 'sequence']
# skipping ['Hymenobacter', 'sp.', 'DG25B', 'plasmid,', 'complete', 'sequence']
# skipping ['Pseudomonas', 'sp.', 'MRSN12121', 'plasmid,', 'complete', 'sequence']
# pMRVIM0812,
# skipping ['Sphingomonas', 'hengshuiensis', 'strain', 'WHSC-8', 'plasmid,', 'complete', 'sequence']
# pHC,
# pHB,
# pHA,
# pBUYP1,
# pP73E,
# pP73D,
# pP73C,
# pP73B,
# pP73A,
# skipping ['Xanthomonas', 'sacchari', 'strain', 'R1', 'plasmid,', 'complete', 'sequence']
# skipping ['Pseudomonas', 'mandelii', 'JR-1', 'plasmid,', 'complete', 'sequence']
# skipping ['Paenibacillus', 'durus', 'strain', 'DSM', '1735', 'plasmid,', 'complete', 'sequence']
# p48,
# p57,
# p123,
# p251,
# pBM19,
# pBM69,
# pBRLA07,
# pBRLA33,
# pCdoos1,
# pCgly1,
# pCIG1485E,
# pLA2,
# pLA5,
# pLA1,
# pLA4,
# pLA3,
# STP2,
# STP1,
# unnamed,
# pWSY,
# pTBH13
# pTBH10
# pPla,
# AbAZ39_p5,
# AbAZ39_p4,
# AbAZ39_p3,
# AbAZ39_p2,
# AbAZ39_p1,
# BM1374166
# pPSP-cd6,
# pPSP-b98,
# pPSP-75c,
# pPSP-100,
# pKPC-56a,
# skipping ['Collimonas', 'arenae', 'strain', 'Cal35', 'plasmid,', 'complete', 'sequence']
# pSYLC,
# pSYLB,
# pSYLA,
# pRgalR602c,
# pRgalR602b,
# pRgalR602a,
# pPSP-3a9,
# pPSP-057,
# pPSP-ee2,
# pPSP-a3e,
# pPSP-26e,
# pKPC-1c5,
# skipping ['Synechococcus', 'sp.', 'UTEX', '2973', 'plasmid,', 'complete', 'sequence']
# skipping ['Synechococcus', 'sp.', 'UTEX', '2973', 'plasmid,', 'complete', 'sequence']
# pSfKp5.2,
# skipping ['Jeotgalibacillus', 'malaysiensis', 'strain', 'D5', 'plasmid,', 'complete', 'sequence']
# pAcX50f,
# pAcX50e,
# pAcX50d,
# pAcX50c,
# pAcX50b,
# pAcX50a,
# pXL100,
# pHsw3,
# pHsw1,
# pHsw2,
# skipping ['Legionella', 'oakridgensis', 'ATCC', '33761', '=', 'DSM', '21215', 'plasmid,', 'complete', 'sequence']
# pCASE2,
# pCASE1,
# p10DC88,
# pHS1,
# phiCFAL8171I,
# skipping ['Yersinia', 'similis', 'strain', '228', 'plasmid,', 'complete', 'sequence']
# pGal_B134,
# pGal_G40,
# pGal_F69,
# pGal_E78,
# pGal_D78,
# pGal_C110,
# pGal_A255,
# pBCT8,
# pBCT77,
# pWNCR9,
# pWNCR15,
# pWNCR64,
# pWNCR47,
# pWNCR12,
# skipping ['Blattabacterium', 'sp.', '(Nauphoeta', 'cinerea)', 'plasmid,', 'complete', 'sequence']
# pBt40,
# p7ME01,
# skipping ['Candidatus', 'Profftella', 'armatura', 'plasmid,', 'complete', 'sequence']
# skipping ['Serratia', 'liquefaciens', 'ATCC', '27592', 'plasmid,', 'complete', 'sequence']
# pCAR1.3
# skipping ['Moraxella', 'catarrhalis', 'strain', 'CCRI-195ME', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhodococcus', 'sp.', 'BH4', 'plasmid,', 'complete', 'sequence']
# pRGUI04,
# pRGUI03,
# pRGUI02,
# pRGUI01,
# unnamed3,
# unnamed2,
# unnamed1,
# pCC2,
# pCC1,
# pCha1,
# 3,
# 2,
# 1,
# pGLO7428.02,
# pGLO7428.03,
# pGLO7428.04,
# pGLO7428.01,
# pTHETHE01,
# pMIC7113.07,
# pMIC7113.02,
# pMIC7113.08,
# pMIC7113.05,
# pMIC7113.03,
# pMIC7113.04,
# pMIC7113.06,
# pMIC7113.01,
# pSYN7502.02,
# pSYN7502.01,
# pTHEOS02,
# pTHEOS01,
# pKLC4,
# pKLC2,
# pKLC3,
# pKLC1,
# pUC06C,
# pUC06B,
# pUC06A,
# pUC08C,
# pUC08B,
# pUC08A,
# pMPJM2,
# pJM2C,
# pJM2B,
# pJM2A,
# pJM1F,
# pJM1E,
# pJM1D,
# pJM1C,
# pJM1B,
# pJM1A,
# pMPJM1,
# pJM3E,
# pJM3D,
# pJM3C,
# pJM3B,
# pJM3A,
# pJM4E,
# pJM4D,
# pJM4C,
# pJM4B,
# pJM4A,
# pGFJ7,
# pGFJ6,
# pGFJ5,
# pGFJ4,
# pGFJ3,
# pGFJ2,
# pGFJ1,
# unnamed1,
# unnamed2,
# unnamed1,
# skipping ['Anabaena', 'sp.', 'WA102', 'plasmid,', 'complete', 'sequence']
# pSSIL1
# pTHEBA.01,
# pDEVAL01,
# pHci1
# pHCW,
# pHCD,
# pTTJL1802,
# pTTJL1801,
# pHCG3B,
# pTCCB09,
# pTHTHE1601,
# skipping ['Rickettsia', 'australis', 'str.', 'Cutlack', 'Plasmid01,', 'complete', 'sequence']
# pMCC_1,
# pPECL-8,
# pPECL-4,
# pPECL-2,
# pPECL-1,
# skipping ['Saprospira', 'grandis', 'str.', 'Lewin', 'plasmid,', 'complete', 'sequence']
# pSICJ18-1,
# pPECL-3,
# pPECL-5,
# pGXY060
# pSMA198,
# pTLIE01,
# pGXY010
# pGXY030
# pGXY070
# pGXY050
# pGXY040
# pGXY020
# pLS1,
# pLS2,
# pRHOM17202,
# pRHOM17201,
# WKp2903,
# pHCG3,
# pOC167,
# pWW2,
# pWW1,
# pUMN179,
# pLBUC01,
# pLBUC02,
# pLBUC03,
# pTRESU01,
# pRKC30SC2,
# pRKC30SC1,
# pTSC8,
# pYP12,
# pYP1,
# pPag2,
# pPag1,
# pRE117-1,
# pRE117-2,
# pEB102
# pEB170
# pPag3,
# pTINT02,
# pTINT01,
# pUT2
# pCHQ1
# pUT1
# pPAN,
# pEp2.6
# pALVIN02,
# pALVIN01,
# pCROD1,
# pCROD2,
# pCROD3,
# pXCEL01,
# pRMAR01,
# pCTU3,
# pCTU2,
# pCTU1,
# pEp36
# pEp05
# pEp03
# pAACI03,
# pAACI02,
# pAACI01,
# pAPRE01,
# pPAU1
# pBGR3,
# pDMC1
# pDMC2
# skipping ['Thermomicrobium', 'roseum', 'DSM', '5159', 'plasmid,', 'complete', 'sequence']
# pCKL1
# pGDIA01,
# pl27,
# pl32,
# pl31,
# pl26,
# pl70,
# pl42,
# pl40,
# pl35,
# pl165,
# pl28,
# pl15,
# pPAES01,
# p74,
# p74,
# pCLL,
# pEXIG02,
# pEXIG01,
# pBT
# pGDIPal5I,
# pGDIPal5II,
# pRMA,
# pCKL555A,
# pACRY08,
# pACRY07,
# pACRY06,
# pACRY05,
# pACRY04,
# pACRY03,
# pACRY02,
# pACRY01,
# pLW1071,
# pDVUL01,
# pHac1
# 3
# 2
# 1
# 1,
# skipping ['Geobacter', 'metallireducens', 'GS-15', 'plasmid,', 'complete', 'genome']
# A,
# pRFdelta,
# pRF,
# pHTA426
# pTT27,
# pCE3
# pCE2
# pWb1
# skipping ['Weissella', 'cibaria', 'strain', 'CMS3', 'plasmid,', 'complete', 'sequence']
# p4PS11,
# p4PS8,
# p3PS8,
# p2PS8,
# p1PS8,
# p158F,
# p158E,
# p158D,
# p158C,
# p158B,
# p158A,
# pUC063E,
# pUC063D,
# pUC063C,
# pUC063B,
# pUC063A,
# skipping ['Lactobacillus', 'rhamnosus', 'strain', 'BFE5264', 'plasmid,', 'complete', 'sequence']
# skipping ['Corynebacterium', 'glutamicum', 'strain', 'CP', 'plasmid,', 'complete', 'sequence']
# unnamed2,
# unnamed1,
# p3,
# p2,
# p1,
# pSNU175-4,
# pSNU175-3,
# pSNU175-2,
# unnamed2,
# unnamed1,
# unnamed,
# p4PS12,
# p3PS12,
# p2PS12,
# p1PS12,
# p4PS6,
# p3PS6,
# p2PS6,
# p1PS6,
# pAHTJS2,
# pAHTJS1,
# p4PS9,
# p3PS9,
# p2PS9,
# p1PS9,
# p4PS3,
# p3PS3,
# p2PS3,
# p1PS3,
# p4PS7,
# p3PS7,
# p2PS7,
# p1PS7,
# p5PS2,
# p4PS2,
# p3PS2,
# p2PS2,
# p1PS2,
# p4PS13,
# p3PS13,
# p2PS13,
# p2PS5,
# p1PS5,
# p4PS4,
# p3PS4,
# p2PS4,
# p1PS4,
# p4PS1,
# p3PS1,
# p2PS1,
# p1PS1,
# skipping ['Yersinia', 'pseudotuberculosis', 'isolate', 'NZYP4713', 'genome', 'assembly,', 'plasmid:', '2']
# pLL074-4.2,
# pLL074-4.1,
# pLJ207-7.3,
# pLJ207-7.2,
# pLJ207-7.1,
# pLH201.2,
# pLH201.1,
# pLH276.3,
# pLH276.2,
# pLH276.1,
# pbcp2,
# pbcp1,
# pJS749-3.2,
# pJS749-3.1,
# pRsp8C3c,
# pRsp8C3b,
# pRsp8C3a,
# pLMG911.2,
# pLMG911.1,
# pICMP7383.3,
# pICMP7383.2,
# pICMP7383.1,
# pLH3.2,
# pLH3.3,
# pLH3.4,
# pLH3.1,
# pLM159.2,
# pLM159.3,
# pLM159.1,
# skipping ['Bacillus', 'pumilus', 'strain', 'GLB197', 'plasmid,', 'complete', 'sequence']
# pLD02,
# pLD01,
# pBPL056,
# unnamed8
# unnamed7,
# unnamed6,
# unnamed5,
# unnamed4,
# unnamed3
# unnamed2,
# unnamed1,
# skipping ['Ralstonia', 'solanacearum', 'strain', 'EP1', 'plasmid,', 'complete', 'sequence']
# skipping ['Leuconostoc', 'mesenteroides', 'subsp.', 'suionicum', 'strain', 'DSM', '20241', 'plasmid,', 'complete', 'sequence']
# pPS2,
# pPS1,
# pNPD4_1,
# pNPD4_2,
# MRG65-300,
# MCP49-600,
# pAMCP48-600,
# plas1,
# pFNE_1,
# p_XCV_3,
# p_XCV_2,
# p_XCV_1,
# p_XAG_1,
# pBhyoB78,
# pEN-119,
# p4PS10,
# p3PS10,
# p2PS10,
# p1PS10,
# pDSMZ13645,
# pDSMZ14563,
# pLS_3,
# pLS_2
# pLS_1
# pINT23,
# pMSMB608,
# unnamed2,
# unnamed1,
# skipping ['Pseudomonas', 'fluorescens', 'strain', 'L228', 'plasmid,', 'complete', 'sequence']
# unnamed3,
# unnamed2,
# unnamed1,
# skipping ['Lactococcus', 'lactis', 'subsp.', 'lactis', 'strain', 'A12', 'genome', 'assembly,', 'plasmid:', 'pA12-4']
# skipping ['Lactococcus', 'lactis', 'subsp.', 'lactis', 'strain', 'A12', 'genome', 'assembly,', 'plasmid:', 'pA12-3']
# skipping ['Lactococcus', 'lactis', 'subsp.', 'lactis', 'strain', 'A12', 'genome', 'assembly,', 'plasmid:', 'pA12-2']
# skipping ['Lactococcus', 'lactis', 'subsp.', 'lactis', 'strain', 'A12', 'genome', 'assembly,', 'plasmid:', 'pA12-1']
# pPDSLzg-1,
# pOZ182,
# pOZ181,
# pOZ172,
# pVs58,
# pBTKNU07-02,
# pBTKNU07-01,
# pR1CP2,
# pR1CP1,
# pASP-135,
# e,
# d,
# c,
# b,
# a,
# mp2,
# mp1,
# unnamed3,
# unnamed2,
# unnamed1,
# pC2014-5,
# pC2014-4,
# pC2014-3,
# pC2014-2,
# pC2014-1,
# unnamed4,
# unnamed3,
# unnamed2,
# unnamed1,
# pML2037,
# skipping ['Vibrio', 'vulnificus', 'strain', 'FORC_017', 'plasmid,', 'complete', 'sequence']
# pRphaN771e,
# pRphaN671d,
# pRphaN771c,
# pRphaN771b,
# pRphaN931d,
# pRphaN931c,
# pRphaN931b,
# pRphaN931a,
# pRphaR744d,
# pRphaR744c,
# pRphaR744b,
# pRphaR744a,
# pRphaN161d,
# pRphaN161c,
# pRphaN161b,
# pRphaN161a,
# pRetR611c,
# pRetR611b,
# pRetR611a,
# pRphaN671e,
# pRphaN671d,
# pRphaN671c,
# pRphaN671b,
# pRphaN671a,
# pRphaN841e,
# pRphaN841d,
# pRphaN841c,
# pRphaN841b,
# pRphaN841a,
# pRphaR723d,
# pRphaR723c,
# pRphaR723b,
# pRphaR723a,
# pRphaR650d,
# pRphaR650c,
# pRphaR650b,
# pRphaR650a,
# pRphaR630d,
# pRphaR630c,
# pRphaR630b,
# pRphaR630a,
# pRphaR620d,
# pRphaR620c,
# pRphaR620b,
# pRphaR620a,
# pRphaN831d,
# pRphaN831c,
# pRphaN831b,
# pRphaN831a,
# skipping ['Ralstonia', 'solanacearum', 'strain', 'YC40-M', 'plasmid,', 'complete', 'sequence']
# pRphaN261d,
# pRphaN261c,
# pRphaN261b,
# pRphaN261a,
# pKPP03,
# pKPP02,
# pKPP01,
# pASP-a58,
# skipping ['Clostridium', 'butyricum', 'strain', 'TOA', 'plasmid,', 'complete', 'sequence']
# pCTK01,
# pBMB8291,
# pBMB9829,
# pBMB71,
# pBMB57,
# pBMB4227,
# pBMB267,
# skipping ['Enterococcus', 'hirae', 'strain', 'R17', 'plasmid,', 'complete', 'sequence']
# unnamed
# unnamed
# unnamed
# skipping ['Hafnia', 'alvei', 'strain', 'HUMV-5920', 'plasmid,', 'complete', 'sequence']
# unnamed2,
# unnamed1,
# skipping ['Rhodovulum', 'sulfidophilum', 'strain', 'SNK001', 'plasmid,', 'complete', 'sequence']
# unnamed2,
# pFiD188,
# pBTBC6,
# pBTBC5,
# pBTBC4,
# pBTBC3,
# pBTBC2,
# pBTBC1,
# skipping ['Pediococcus', 'damnosus', 'strain', 'TMW', '2.1535', 'plasmid,', 'complete', 'sequence']
# pL21535-4,
# pL21535-3,
# pL21535-2,
# pL21535-1,
# pL21534-4,
# pL21534-3,
# pL21534-2,
# pL21534-1,
# pL21532-5,
# pL21532-4,
# pL21532-3,
# pL21532-2,
# pL21532-1,
# pHD120345,
# pHD120161,
# pHD120112,
# pHD120039,
# pHD120038,
# pHD120017,
# pPsCRG01-3,
# pPsCRG01-2,
# pPsCRG01-1,
# pPSCRG01-4,
# pMKC07,
# pMKC05,
# pMKC04,
# pMKC03,
# pMKC02,
# pMKC01,
# Unnamed
# pCfviP3,
# pCfviMP2,
# pCfviMP1,
# QpRS,
# pCCON16,
# pCCON31,
# unnamed,
# pUC109F,
# pUC109E,
# pUC109D,
# pUC109C,
# pUC109B,
# pUC109A,
# p229E,
# p229D,
# p229C,
# p229B,
# p229A,
# p275D,
# p275C,
# p275B,
# p275A,
# pKrDSM16656S,
# pKrDSM16656L,
# unnamed_1,
# unnamed_3,
# unnamed_2,
# pL6-1,
# skipping ['Bacillus', 'amyloliquefaciens', 'strain', 'S499', 'plasmid,', 'complete', 'sequence']
# skipping ['Pantoea', 'ananatis', 'strain', 'R100', 'plasmid,', 'complete', 'sequence']
# pMBL96,
# pMBL287,
# pMBL128,
# pKPYL2,
# pKPYL1,
# pL21536-2,
# pL21536-1,
# pL21533-7,
# pL21533-6,
# pL21533-5,
# pL21533-4,
# pL21533-3,
# pL21533-2,
# pL21533-1,
# pDhc6,
# skipping ['Lysinibacillus', 'sphaericus', 'III(3)7', 'plasmid,', 'complete', 'sequence']
# pPSCRG02-4,
# pPSCRG02-2,
# pPSCRG02-1,
# pBT1850007,
# pBT1850046,
# pBT1850012,
# pBT1850042,
# pBT1850054,
# pBT1850055,
# pBT1850294,
# pBT1850636,
# skipping ['Ralstonia', 'solanacearum', 'strain', 'IBSBF1503', 'plasmid,', 'complete', 'sequence']
# pUW163b,
# pUW163a,
# skipping ['Ralstonia', 'solanacearum', 'strain', 'UW163', 'plasmid,', 'complete', 'sequence']
# skipping ['Lysinibacillus', 'sphaericus', 'strain', 'OT4b.25', 'plasmid,', 'complete', 'sequence']
# pAM1A3,
# pSHB26,
# pJFP838A,
# pJFP838C,
# pJFP838D,
# pJFP838E,
# pJFP55K,
# pJFP55J,
# pJFP55H,
# pJFP55F,
# pOXA58-AP_882,
# pNDM-AP_882,
# pPME5,
# genomic
# genomic
# skipping ['Rhodobacter', 'sphaeroides', 'strain', 'MBTLJ-8', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhodobacter', 'sphaeroides', 'strain', 'MBTLJ-8', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhodobacter', 'sphaeroides', 'strain', 'MBTLJ-8', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhodobacter', 'sphaeroides', 'strain', 'MBTLJ-8', 'plasmid,', 'complete', 'sequence']
# p48A,
# pKK8
# pKK7
# pKK6
# pKK5
# pKK4
# pKK3
# pKK2
# pKK1
# pFORC3,
# pRY68,
# skipping ['Paenibacillus', 'peoriae', 'strain', 'HS311', 'plasmid,', 'complete', 'sequence']
# pBR3,
# unnamed2,
# unnamed1,
# pYWC2-8-6,
# pYWC2-8-5,
# pYWC2-8-4,
# pYWC2-8-3,
# pYWC2-8-2,
# pYWC2-8-1,
# skipping ['Fusobacterium', 'hwasookii', 'ChDC', 'F206', 'plasmid,', 'complete', 'sequence']
# unnamed2,
# unnamed1,
# unnamed
# unnamed
# unnamed
# unnamed
# pAhD4-4,
# pAhD4-3,
# pAhD4-2,
# pAhD4-1,
# pCMA2,
# pCMA1,
# pSF002,
# pSF001,
# pLRE138,
# pCRE138,
# p63039,
# skipping ['Clostridium', 'butyricum', 'strain', 'JKY6D1', 'plasmid,', 'complete', 'sequence']
# :
# pZD02,
# skipping ['Fusobacterium', 'hwasookii', 'ChDC', 'F300', 'plasmid,', 'complete', 'sequence']
# :
# pBC25416,
# pPSA1-4,
# pPSA1-3,
# pPSA1-2,
# pPSA1-1,
# skipping ['Ralstonia', 'solanacearum', 'strain', 'UY031', 'plasmid,', 'complete', 'sequence']
# pPSB1-4,
# pPSB1-3,
# pPSB1-2,
# pPSB1-1,
# pCM2,
# pCM1,
# pCS3,
# pCS2,
# pCS1,
# skipping ['Geobacillus', 'stearothermophilus', '10', 'plasmid,', 'complete', 'sequence']
# skipping ['Lactobacillus', 'helveticus', 'strain', 'KLDS1.8701', 'plasmid,', 'complete', 'sequence']
# unnamed4,
# unnamed3,
# unnamed2,
# unnamed1,
# pHS18-9,
# pHS18-8,
# pHS18-7,
# pHS18-6,
# pHS18-5,
# pHS18-4,
# pHS18-3,
# pHS18-2,
# pHS18-1,
# pGR8,
# pBTHD521-6,
# pBTHD521-5,
# pBTHD521-4,
# pBTHD521-3,
# pBTHD521-2,
# pBTHD521-1,
# p6411-66.409kb,
# pKLE04,
# pKLE03,
# pKLE02,
# pKLE01,
# pRmeGR4d,
# pRmeGR4c,
# pRmeGR4b,
# pRmeGR4a,
# p1,
# cp32-5,
# cp32-3,
# cp32-4,
# cp32-9,
# lp38,
# lp28-8,
# lp28-4,
# lp28-3,
# lp28-2,
# lp28-1,
# lp17,
# cp26,
# lp54,
# pDSM20484,
# pSC2,
# pCAV1043-97,
# pKPC_CAV1043,
# pCAV1043-58,
# pCAV1043-51,
# pCAV1043-10,
# pCAV1043-1919,
# pKPC_CAV1741,
# pCAV1741-110,
# pCAV1741-101,
# pCAV1741-16,
# pCAV1741-3223,
# pCAV1741-1916,
# pKPC_CAV1321-244,
# pCAV1321-135,
# pCAV1321-71,
# pKPC_CAV1321-45,
# pCAV1321-4938,
# pCAV1321-4310,
# pCAV1321-3820,
# pCAV1321-3223,
# pCAV1321-1916,
# pYC2226,
# pYC20,
# pYC11,
# pYC10,
# pYC6,
# pYC5,
# pYC4,
# pYC3,
# pYC1,
# pR2,
# pR1,
# skipping ['Moraxella', 'bovoculi', 'strain', '58069', 'plasmid,', 'complete', 'sequence']
# CSK29544_3p,
# CSK29544_2p,
# CSK29544_1p,
# skipping ['Citrobacter', 'amalonaticus', 'Y19', 'plasmid,', 'complete', 'sequence']
# skipping ['Francisella', 'tularensis', 'subsp.', 'tularensis', 'str.', 'SCHU', 'S4', 'substr.', 'NR-28534', 'plasmid,', 'complete', 'sequence']
# pRSLBG43,
# pRLLBG43,
# pRLCBG43,
# pTi,
# pAt,
# skipping ['Campylobacter', 'fetus', 'subsp.', 'venerealis', 'str.', '84-112', 'integrative', 'conjugative', 'element']
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXCAW58,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pXAC64,
# pXCAW58,
# pXCAW19,
# pXAC64,
# pXAC64,
# pXAC33,
# pXAC64,
# pXAC33,
# pBIN_1,
# pBIN_2,
# pBVB_1,
# 1,
# 2,
# 3,
# pCI3,
# pCI2,
# pCI1,
# pLM1,
# pAH06-06-3,
# pAH06-06-2,
# pAH06-06-1,
# pBMB48,
# pBMB51,
# pBMB68,
# pBMB76,
# pBMB92,
# pBMB232,
# p6411-9.012kb,
# pMAH135
# skipping ['Francisella', 'philomiragia', 'strain', 'GA01-2794', 'plasmid,', 'complete', 'sequence']
# 4,
# 1,
# 2,
# 3,
# 5,
# 6,
# 7,
# 1,
# 2,
# 4,
# 3,
# skipping ['Francisella', 'tularensis', 'subsp.', 'novicida', 'strain', 'DPG', '3A-IS', 'plasmid,', 'complete', 'sequence']
# unnamed1,
# unnamed2,
# pYAC_1,
# pYAC_2,
# pYAB,
# pCD,
# unnsmrf,
# skipping ['Francisella', 'tularensis', 'subsp.', 'novicida', 'F6168', 'plasmid,', 'complete', 'sequence']
# pFPI_1,
# pFPJ_1,
# skipping ['Francisella', 'philomiragia', 'strain', 'O#319-029', 'plasmid,', 'complete', 'sequence']
# pFPK_1,
# pFPK_2,
# skipping ['Bacillus', 'thuringiensis', 'strain', '97-27', 'plasmid,', 'complete', 'sequence']
# pBFQ,
# pBGN_1,
# pBGN_2,
# pBGN_3,
# pBMV_2,
# pBMV_1,
# pBMV_4,
# pBMV_6,
# pBMV_5,
# pBMV_3,
# pBMX_1,
# pBMX_2,
# pBMX_3,
# pLBPC-2
# pLBPC-1
# p6411-89.111kb,
# pSb31l,
# pSb31s,
# pRetIE4803d,
# pRetIE4803c,
# pRetIE4803b,
# pRetIE4803a,
# pEA320
# plca36,
# lp54,
# cp26,
# unnamed,
# pCTN1046,
# pLMP1046,
# pMP1046B,
# pMP1046A,
# p319,
# p380,
# pBMB8,
# pBMB7,
# pBMB12,
# pBMBLin15,
# pBMB47,
# pBMB55,
# pBMB71,
# pBMB126,
# pBMB267,
# pBMB426,
# skipping ['Neorhizobium', 'galegae', 'chromid', 'pHAMBI540a,', 'complete', 'sequence']
# pLBCZ-2
# pLBCZ-1
# skipping ['Corynebacterium', 'glutamicum', 'strain', 'B253', 'plasmid,', 'complete', 'sequence']
# unnamed,
# pCul210931,
# pNCDO2118,
# Apa386Bp2,
# skipping ['Providencia', 'stuartii', 'strain', 'ATCC', '33672', 'plasmid,', 'complete', 'sequence']
# 2,
# 1,
# pCFF04554,
# pCFV97608-2,
# pCFV97608-1,
# pHAMBI1141b,
# skipping ['Neorhizobium', 'galegae', 'chromid', 'pHAMBI1141a,', 'complete', 'sequence']
# p67vangNB10,
# pOCN014,
# pSymB,
# pSymA,
# pBMB400,
# pBMB293,
# pBMB95,
# pBMB69,
# pBMB11,
# pBMB8513,
# pBMB8240,
# pBMB7921,
# pBMB2062,
# pENT-4bd,
# pENT-08e,
# pKPC-47e,
# pENT-d4a,
# pENT-8a4,
# pENT-576,
# skipping ['Bacillus', 'mycoides', 'strain', '219298', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'mycoides', 'strain', '219298', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'mycoides', 'strain', '219298', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'mycoides', 'strain', '219298', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'mycoides', 'strain', '219298', 'plasmid,', 'complete', 'sequence']
# pPA21A,
# pTTS12,
# pCBJ,
# p93U204,
# pXAC33,
# Apa386Bp5,
# Apa386Bp3,
# Apa386Bp7,
# Apa386Bp6,
# Apa386Bp4,
# Apa386Bp1,
# skipping ['Lactobacillus', 'paracasei', 'N1115', 'plasmid,', 'complete', 'sequence']
# skipping ['Lactobacillus', 'paracasei', 'N1115', 'plasmid,', 'complete', 'sequence']
# skipping ['Lactobacillus', 'paracasei', 'N1115', 'plasmid,', 'complete', 'sequence']
# skipping ['Lactobacillus', 'paracasei', 'N1115', 'plasmid,', 'complete', 'sequence']
# 9,
# 8,
# 7,
# 6,
# 5,
# 4,
# 3,
# 2,
# 1,
# pZM1402304,
# pZM1402303,
# pZM1402302,
# pZM1402301,
# pBMB14,
# pBMBLin15,
# pBMB8513,
# pBMB7635,
# pBMB2062,
# pBMB431,
# pBMB299,
# pBMB95,
# pBMB74,
# pBMB65,
# pBMB64,
# pBMB46,
# unnamed1,
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'CB782', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'CB782', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'CB782', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'WSM1689', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'WSM1689', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'WSM1689', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'WSM1689', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhizobium', 'leguminosarum', 'bv.', 'trifolii', 'WSM1689', 'plasmid,', 'complete', 'sequence']
# skipping ['Fusobacterium', 'nucleatum', 'subsp.', 'animalis', '7_1', 'plasmid,', 'complete', 'sequence']
# pKEC-a3c,
# skipping ['Fusobacterium', 'nucleatum', 'subsp.', 'vincentii', '3_1_27', 'plasmid,', 'complete', 'sequence']
# unnamed,
# pLIB119,
# unnamed2,
# pZM1252605,
# pZM1252604,
# pZM1252603,
# pZM1252602,
# pZM1252601,
# pBMB67,
# pBMB94,
# pBMB7635,
# pBMB7921,
# pBMB8240,
# pBMB8513,
# pBMB11,
# pBMB53,
# pBMB293,
# pBMB422,
# pBMB2062,
# pPLA2_10,
# skipping ['Rhodococcus', 'pyridinivorans', 'SB3094', 'plasmid,', 'complete', 'sequence']
# skipping ['Rhodococcus', 'pyridinivorans', 'SB3094', 'plasmid,', 'complete', 'sequence']
# p2,
# p1,
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'str.', 'CP4', '=', 'NRRL', 'B-14023', 'plasmid,', 'complete', 'sequence']
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'str.', 'CP4', '=', 'NRRL', 'B-14023', 'plasmid,', 'complete', 'sequence']
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'str.', 'CP4', '=', 'NRRL', 'B-14023', 'plasmid,', 'complete', 'sequence']
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'str.', 'CP4', '=', 'NRRL', 'B-14023', 'plasmid,', 'complete', 'sequence']
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'str.', 'CP4', '=', 'NRRL', 'B-14023', 'plasmid,', 'complete', 'sequence']
# pQY024
# pQY082
# pQY003
# pQY039
# pQY182
# pMK12478,
# skipping ['Vibrio', 'campbellii', 'ATCC', 'BAA-1116', 'plasmid,', 'complete', 'sequence']
# pRECF1,
# 2,
# 1,
# pRetMIM1f,
# pRetNIM1c,
# pRetMIM1e,
# pRetMIM1d,
# pRetMIM1b,
# pRetMIM1a,
# pLOCK919,
# p75,
# pLRI04,
# pLRI01,
# pLRI06,
# pLRI05,
# pLRI02,
# pLRI03,
# pCLOPA01,
# pSCDB14,
# pRSJ17_1,
# pRSMBB,
# pRSMBA,
# skipping ['Propionibacterium', 'acnes', 'HL096PA1', 'plasmid,', 'complete', 'sequence']
# pKB290-8
# pKB290-6
# pKB290-3
# pKB290-9
# pKB290-7
# pKB290-5
# pKB290-4
# pKB290-2
# pKB290-1
# clone
# pCC5.2_M,
# pCB2.4_M,
# pSYSA_M,
# pCA2.4_M,
# clone
# clone
# clone
# clone
# clone
# clone
# pSP291-1,
# pSP291-3,
# pSP291-2,
# pSZ4,
# pEA1509_A,
# pW56,
# skipping ['Gluconobacter', 'oxydans', 'H24', 'plasmid,', 'complete', 'sequence']
# pCIS4,
# pCIS2,
# pCIS6,
# pCIS1,
# pCIS3,
# pCIS5,
# pCIS7,
# pCIS8,
# pcpWSRTE30,
# pcpWC,
# pcpNJ1,
# pcpMN,
# pcpM56,
# pZZ6.01,
# pZZ6.02,
# pZZ6.03,
# N40_lp28-4,
# N40_lp28-5,
# N40_cp26,
# N40_cp32-4,
# N40_cp32-12,
# N40_cp32-7,
# N40_cp32-9,
# N40_lp25,
# N40_lp17,
# N40_cp32-10,
# N40_lp38,
# N40_lp28-2,
# N40_lp36,
# N40_cp9,
# N40_cp32-5,
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# JD1
# pFL6-60,
# cp26,
# lp54,
# PAGR_p,
# pQA549,
# pQA504,
# pQA554,
# pQA518,
# pCV56D,
# pCV56B,
# pCV56A,
# pCV56C,
# pCV56E,
# pBD-II,
# pLC2W,
# pH10,
# lp38,
# lp54,
# lp32-10,
# lp28-8,
# lp28-7,
# cp32-11,
# lp17,
# lp28-2,
# lp28-4,
# lp28-3,
# cp32-7,
# cp32-1,
# cp26,
# cp32-9,
# cp32-5,
# cp32-3,
# cp32-12,
# BLNIAS_P2,
# BLNIAS_P1,
# pMC1,
# skipping ['Pasteurella', 'multocida', 'subsp.', 'multocida', 'str.', 'HN06', 'plasmid,', 'complete', 'sequence']
# pPANA10
# pENTAS02,
# pENTAS01,
# pDRPIS7493,
# pZYMOP02,
# pZYMOP01,
# pSGG1
# p157F-NC2
# p157F-NC1
# skipping ['Lactobacillus', 'delbrueckii', 'subsp.', 'bulgaricus', 'ND02', 'plasmid,', 'complete', 'sequence']
# N40_lp54,
# JD1_lp54,
# pCM2
# pCM1
# 3,
# 2,
# 1,
# pKW4,
# unitig_2,
# p41-4,
# p41-3,
# p41-2,
# p41-1,
# skipping ['Bacillus', 'cereus', 'strain', 'FORC021', 'plasmid,', 'complete', 'sequence']
# unnamed,
# pHPYLPMSS1,
# pX01,
# pB,
# pA,
# pRI113_6,
# pRI113_5,
# pRI113_4,
# pRI113_3,
# pRI113_2,
# pRI113_1,
# p9853_B,
# p9853_A,
# p1_ISMMS_VRE12,
# p2_ISMMS_VRE12,
# p3_ISMMS_VRE9,
# p4_ISMMS_VRE9,
# p1_ISMMS_VRE9,
# p2_ISMMS_VRE9,
# unnamed1,
# unnamed,
# unnamed1,
# pXO2,
# pXO1,
# pPsa22180b,
# pPsa22180a,
# pPsa20586,
# pLP12-6,
# pLP12-5,
# pLP12-4,
# pLP12-3,
# pLP12-2,
# pLP12-1,
# unnamed2,
# unnamed1,
# unnamed3,
# unnamed2,
# unnamed1,
# skipping ['Bacillus', 'subtilis', 'strain', 'KH2', 'plasmid,', 'complete', 'sequence']
# pE1_3,
# pE1_13,
# pE1_29,
# pE1_230,
# pQH111L,
# pMF1298-2,
# pMF1298-1,
# pNPD12_2,
# pNPD12_1,
# unnamed6,
# unnamed5,
# unnamed4,
# unnamed3,
# unnamed2,
# unnamed1,
# pXO2,
# pXO1,
# skipping ['Legionella', 'pneumophila', 'subsp.', 'pneumophila', 'strain', 'FFI102', 'plasmid,', 'complete', 'sequence']
# skipping ['Legionella', 'pneumophila', 'subsp.', 'pneumophila', 'strain', 'FFI103', 'plasmid,', 'complete', 'sequence']
# skipping ['Legionella', 'pneumophila', 'subsp.', 'pneumophila', 'strain', 'FFI329', 'plasmid,', 'complete', 'sequence']
# unamed2,
# unnamed1,
# unnamed1,
# unnamed1,
# unnamed1,
# unnamed1,
# pl6,
# pl5,
# pl4,
# pl3,
# pl2,
# pl1,
# unnamed,
# skipping ['Pseudomonas', 'syringae', 'pv.', 'actinidiae', 'ICMP', '18708', 'plasmid,', 'complete', 'sequence']
# pRF23,
# pMSMB2035,
# pMSMB1471,
# pLY7801,
# unnamed2,
# unnamed1,
# unnamed3,
# unnamed2,
# unnamed1,
# unnamed3,
# unnamed2,
# unnamed1,
# skipping ['Legionella', 'pneumophila', 'strain', 'Lpm7613', 'genome', 'assembly,', 'plasmid:', '2']
# skipping ['Legionella', 'pneumophila', 'strain', 'OLDA', 'plasmid,', 'complete', 'sequence']
# LZ227p5,
# LZ227p3,
# LZ227p2,
# LZ227p4,
# LZ227p1,
# pXO2,
# pXO1,
# LZ206p3,
# LZ206p1,
# LZ206p2,
# pBCA1,
# pBCA3,
# pBCA2,
# skipping ['Pseudomonas', 'syringae', 'pv.', 'actinidiae', 'ICMP', '18884', 'plasmid,', 'complete', 'sequence']
# skipping ['Chlamydophila', 'pneumoniae', 'LPCoLN', 'plasmid,', 'complete', 'sequence']
# pRCB133,
# pBM300,
# pBM100,
# pBM200,
# pBM400,
# pBM500,
# pBM700,
# pBM600,
# 2
# 1
# pEA29
# pKF147A,
# pSMON01,
# p9785L,
# pZA1003,
# pZA1002,
# pZA1001,
# sequence,
# p9785S,
# pROB02
# pROB01
# pKNR
# pKNR02
# pKNR01
# pBHWA1,
# ZS7_lp54,
# ZS7_lp25,
# ZS7_lp28-4,
# ZS7_lp17,
# ZS7_lp28-3,
# ZS7_lp28-1,
# ZS7_lp28-2,
# ZS7_lp36,
# ZS7_cp32-4,
# ZS7_cp32-12,
# ZS7_cp32-1,
# ZS7_cp26,
# ZS7_cp32-9,
# ZS7_cp32-3+10,
# pQpRS_K_Q154,
# pTGL1
# pYPTS01,
# pXFAS01,
# pLCK1,
# pLCK4,
# pLCK3,
# pLCK2,
# pFPHI01,
# QpH1,
# pCKO2,
# pCKO3,
# pESA3,
# pESA2,
# pQpDG,
# pCGR1
# 2,
# 1,
# 5,
# 4,
# 3,
# 2,
# 1,
# pLEUM1,
# pSSP2,
# pSSP1,
# pGOX5,
# pGOX4,
# pGOX3,
# pGOX2,
# pGOX1,
# pXF1.3,
# pSYSX
# pSYSA
# pSYSM
# pYJ016
# pE88,
# pXFPD1.3,
# pDOJH10S,
# pDOJH10L,
# pCP13
# skipping ['Mesorhizobium', 'loti', 'MAFF303099', 'pMLa', 'DNA,', 'complete', 'genome']
# pMLb
# pMoPn,
# pXF51,
# CtrE-103,
# skipping ['Staphylococcus', 'epidermidis', 'isolate', 'BPH0662', 'genome', 'assembly,', 'plasmid:', '3']
# skipping ['Staphylococcus', 'epidermidis', 'isolate', 'BPH0662', 'genome', 'assembly,', 'plasmid:', '2']
# pRML05,
# pRML04,
# pRML02,
# pRML01,
# p3,
# p5,
# p4,
# p2,
# p1,
# pSH108,
# pBcp895-1,
# pBcn842-1,
# unnamed3,
# unnamed2,
# unnamed1,
# pXO2,
# pXO1,
# skipping ['Pseudomonas', 'syringae', 'UMAF0158', 'plasmid,', 'complete', 'sequence']
# pSmUNAM836,
# pMK06,
# pMK05,
# pMK09,
# pMK01,
# pMK08,
# pMK02,
# pMK10,
# pMK07,
# pMK04,
# pMK03,
# skipping ['Yersinia', 'pestis', 'CO92', 'plasmid,', 'complete', 'sequence']
# skipping ['Yersinia', 'pestis', 'CO92', 'plasmid,', 'complete', 'sequence']
# pWCF-TC1,
# skipping ['Helicobacter', 'pylori', 'strain', '7C', 'plasmid,', 'complete', 'sequence']
# unnamed2,
# unnamed1,
# LZ95p2,
# LZ95p1,
# pBCEN1232,
# skipping ['Yersinia', 'enterocolitica', 'strain', 'KNG22703', 'plasmid,', 'complete', 'sequence']
# p34977-263.138kb,
# p34977-5.006kb,
# pCD1,
# pMT1,
# pCD1,
# pMT1,
# pPCP,
# pCD,
# pMT,
# pCD,
# pMT,
# pCD,
# pMT,
# pCD1,
# pMT1,
# pCD,
# pMT,
# unnamed,
# skipping ['Chlamydia', 'trachomatis', 'strain', 'Ia/CS190/96', 'plasmid,', 'complete', 'sequence']
# skipping ['Chlamydia', 'trachomatis', 'strain', 'F/CS847/08', 'plasmid,', 'complete', 'sequence']
# skipping ['Chlamydia', 'trachomatis', 'strain', 'E/CS1025/11', 'plasmid,', 'complete', 'sequence']
# pBFC_3,
# pBFC_2,
# pBFC_1,
# LBPp5,
# LBPp4,
# LBPp3,
# LBPp2,
# LBPp1,
# pKPC_CAV1311,
# pCAV1311-3223,
# pKPC_CAV1411,
# pKPC_CAV1669,
# pCAV1668-85,
# pKPC_CAV1668,
# skipping ['Pseudomonas', 'syringae', 'pv.', 'syringae', 'HS191', 'plasmid,', 'complete', 'sequence']
# pFORC2,
# skipping ['Chlamydia', 'trachomatis', 'strain', 'L2b/CS19/08', 'plasmid,', 'complete', 'sequence']
# pXO2,
# pXO1,
# pCD,
# pMT,
# pPCP,
# pMT,
# pPCP,
# pCD,
# pPCP,
# pMT,
# 2,
# 1,
# 3,
# pMT,
# pCD,
# pCD,
# pCD,
# pCD,
# pMT,
# pPCP,
# pBFR_2,
# pBFR_1,
# pBFR_3,
# pCD1,
# pMT1,
# pPCP1,
# unnamed2,
# unnamed1,
# unnamed3,
# skipping ['Yersinia', 'enterocolitica', 'strain', 'WA', 'plasmid,', 'complete', 'sequence']
# pMT,
# pCD,
# pPCP,
# pMT,
# pCD,
# pMT,
# pCD,
# pPCP
# skipping ['Bacillus', 'anthracis', 'str.', 'Turkey32', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'anthracis', 'str.', 'Turkey32', 'plasmid,', 'complete', 'sequence']
# pXO1,
# pXO2,
# pBFI_3,
# pBFI_1,
# pBFI_4,
# pBFI_5,
# pBFI_2,
# pBFI_6,
# pBFI_7,
# pBCX01,
# pBC210,
# skipping ['Bacillus', 'cereus', 'strain', 'FM1', 'plasmid,', 'complete', 'sequence']
# pBFH_1,
# pXO1,
# pXO2,
# 1,
# 2,
# pXO1,
# pXO2,
# pXO1,
# pXO2,
# pXO1,
# pXO2,
# 1,
# 2,
# 1,
# 1,
# 2,
# pXO1,
# pBCO_4,
# pBCO_3,
# skipping ['Bacillus', 'cereus', 'D17', 'plasmid,', 'complete', 'sequence']
# 1,
# 2,
# pBCO_1,
# pBCO_2,
# pBCO_5,
# pBGM,
# pXO1,
# pXO2,
# skipping ['Bacillus', 'cereus', '03BB102', 'plasmid,', 'complete', 'sequence']
# LBPp7,
# pXO2,
# pXO1,
# pSMC2
# pSMC1
# pBCX01,
# pBCN,
# pKPC-860,
# pENT-e56,
# pENT-c88,
# p34977-43.621kb,
# p34983-328.905kb,
# p34983-43.621kb,
# p34983-59.134kb,
# p34399-43.500kb,
# p34399-121.660kb,
# p34399-106.698kb,
# pCBG,
# pCBI,
# LBPp6,
# pKPC-f91,
# pKPC-272,
# pKEC-39c,
# pX02,
# pX01,
# pXO2,
# skipping ['Bacillus', 'anthracis', 'str.', 'Vollum', 'plasmid,', 'complete', 'sequence']
# skipping ['Bacillus', 'anthracis', 'str.', 'Vollum', 'plasmid,', 'complete', 'sequence']
# 1,
# 2,
# 3,
# 4,
# skipping ['Staphylococcus', 'epidermidis', 'strain', 'SEI', 'plasmid,', 'complete', 'sequence']
# 1,
# 2,
# pXO2,
# pXO1,
# pCC1557,
# pEFT110,
# unnamed,
# skipping ['Neisseria', 'gonorrhoeae', 'MS11', 'plasmid,', 'complete', 'sequence']
# pLP-ZJ103,
# pLP-ZJ102,
# pLP-ZJ101,
# Lp16I,
# Lp16G,
# Lp16D,
# Lp16B,
# Lp16L,
# Lp16H,
# Lp16F,
# Lp16E,
# Lp16C,
# Lp16A,
# pL2/434/Bu(i),
# pSmWW4,
# p2HPAKL117,
# p1HPAKL117,
# p17BNRP
# p04,
# p03,
# p01,
# p02,
# tig00000004,
# tig00000003,
# tig00000002,
# tig00000001,
# tig00000005,
# tig00000004,
# tig00000003,
# tig00000002,
# unitig_5,
# unitig_4,
# unitig_3,
# unitig_2,
# unitig_1,
# unitig_3,
# unitig_2,
# unitig_1,
# pCA16,
# unitig_1,
# pPLP2.1,
# pPLP1,
# pMM170,
# pMM259,
# pMM593,
# p9912D,
# pSAN1-06-0624,
# :
# pBMJS25R,
# pL3404
# pL1224
# pSotonIa1
# pL2bUCH2
# pL1115
# skipping ['Legionella', 'pneumophila', 'subsp.', 'pneumophila', 'LPE509', 'plasmid,', 'complete', 'sequence']
# pHPOK310
# pNB2354_1,
# p2HPAKL86,
# p1HPAKL86,
# pA363
# EFD32pB,
# EFD32pA,
# pLELO,
# pHPB14,
# pHPELS37,
# AUS0004_p2,
# AUS0004_p1,
# AUS0004_p3,
# pNCcld
# pNC2
# pNC1
# pNC3
# pNC4
# pSn,
# HPP12,
# pHPG27,
# pHPAG1,
# pLPP,
# pLPL,
# unnamed,
# pCOS502,
# pCMCVTAb2-Ab66,
# pCMCVTAb1-Ab66,
# pCMCVTAb1-Ab59,
# pCMCVTAb2-Ab4,
# pCMCVTAb1-Ab4,
# :
# pCTDLC1,
# pHPPN120,
# pHPSNT,
# skipping ['Helicobacter', 'pylori', 'SouthAfrica7', 'plasmid,', 'complete', 'sequence']
# skipping ['Helicobacter', 'pylori', 'Gambia94/24', 'plasmid,', 'complete', 'sequence']
# skipping ['Helicobacter', 'pylori', 'Lithuania75', 'plasmid,', 'complete', 'sequence']
# pHPSAT464,
# pHPv225d,
# skipping ['Yersinia', 'pestis', 'A1122', 'plasmid,', 'complete', 'sequence']
# skipping ['Yersinia', 'pestis', 'A1122', 'plasmid,', 'complete', 'sequence']
# pMT1,
# pCD1,
# pPCP1,
# pPCY1,
# pMT1,
# pCD1,
# pEcWSU1_A,
# pST-III,
# 105.5R(r)p,
# p3BKT015925,
# p1BKT015925,
# p2BKT015925,
# p4BKT015925,
# p5BKT015925,
# pHPPC4,
# skipping ['Helicobacter', 'pylori', 'B8', 'HPB8p', 'plasmid']
# pWc,
# pPCP1,
# pMT1,
# pCD1,
# pMT-pPCP,
# new_pCD,
# pCLI,
# MT,
# CD,
# pPCP,
# pMT,
# pCD,
# pPCP,
# pMT,
# pCTA,
# pSHaeC
# pSHaeB
# pSHaeA
# pSERP,
# pMT-1,
# pALAC4-2,
# unnamed1,
# pBJ83
# pAF-401,
# pAF-673,
# skipping ['Acinetobacter', 'baumannii', 'strain', 'HRAB-85', 'plasmid,', 'complete', 'sequence']
# skipping ['Vibrio', 'parahaemolyticus', 'strain', 'FORC_022', 'plasmid,', 'complete', 'sequence']
# pPA7790,
# pCJDM210S,
# pCJDM210L,
# pCJDM204S,
# pCJDM204L,
# pCCDM224L,
# pCCDM224S,
# pCCDM116S,
# pCCDM116L,
# pTet-M129,
# pCCDM108S,
# pCCDM108L,
# pCCDM105S,
# pCCDM105L,
# pCCDM33S,
# pCJDM100,
# pCCDM183,
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB03', 'plasmid,', 'complete', 'sequence']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB06', 'plasmid,', 'complete', 'sequence']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB08', 'plasmid,', 'complete', 'sequence']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB04', 'plasmid,', 'complete', 'sequence']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB07,', 'complete', 'genome']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB01', 'plasmid,', 'complete', 'sequence']
# skipping ['Acinetobacter', 'baumannii', 'strain', 'KAB05', 'plasmid,', 'complete', 'sequence']
# pCC14983A-3,
# pCC14983A-2,
# pCC14983A-1,
# pCJ14980A,
# pBM413,
# pAba3207b,
# pAba3207a,
# pFORC14,
# pCJDM67
# pCJDM67
# pCJDM202,
# pNSUI060b,
# pNSUI060a,
# skipping ['Campylobacter', 'jejuni', 'strain', 'RM3194', 'plasmid,', 'complete', 'sequence']
# pNGBS128,
# unnamed2,
# unnamed1,
# pKBN10P02143,
# pOR12CC42,
# pOR12TET,
# pOR12Vir,
# :
# skipping ['Acinetobacter', 'calcoaceticus', 'strain', 'NCTC7364', 'genome', 'assembly,', 'plasmid:', '2']
# skipping ['Enterococcus', 'faecium', 'isolate', 'Ef_aus00233', 'genome', 'assembly,', 'plasmid:', '6']
# skipping ['Enterococcus', 'faecium', 'isolate', 'Ef_aus00233', 'genome', 'assembly,', 'plasmid:', '5']
# skipping ['Enterococcus', 'faecium', 'isolate', 'Ef_aus00233', 'genome', 'assembly,', 'plasmid:', '4']
# skipping ['Enterococcus', 'faecium', 'isolate', 'Ef_aus00233', 'genome', 'assembly,', 'plasmid:', '3']
# skipping ['Enterococcus', 'faecium', 'isolate', 'Ef_aus00233', 'genome', 'assembly,', 'plasmid:', '2']
# pccdm1,
# pXI1,
# pAB3,
# pAB04-2,
# pAB04-1,
# pAB386,
# p3AB5075,
# p2AB5075,
# p1AB5075,
# pIOMTU433
# pFB1TET,
# pCC42,
# pCj2,
# pCj1,
# pA1-1,
# pVPUCMV,
# p6200-9.327kb,
# p6200-47.274kb,
# p6200-114.848kb,
# pABLAC2,
# pABLAC1,
# pRM1875_3.4kbp,
# pRM1875_3.3kb,
# pRM1875_2.4kb,
# pRM1875_35kb,
# pRM5611_48kb,
# ZW85p2,
# pAbNDM-1,
# pCC42yr,
# pN29710-1,
# skipping ['Campylobacter', 'jejuni', 'subsp.', 'jejuni', '00-2544', 'plasmid,', 'complete', 'sequence']
# pN29710-2,
# pBJAB0715,
# p3BJAB0868,
# p2BJAB0868,
# p1BJAB0868,
# p2BJAB07104,
# p1BJAB07104,
# 1,
# 2,
# pD1279779,
# unnamed3,
# unnamed2,
# unnamed1,
# p63-3
# p63-2,
# p63-1,
# unnamed,
# pOAAA2,
# p268-3
# p268-2
# p268-1,
# unnamed1,
# pSUR1B,
# pVir,
# pTet,
# pMDR-ZJ06,
# ABKp1,
# ABKp2,
# pACICU2,
# pACICU1,
# p3ABAYE,
# p4ABAYE,
# p2ABAYE,
# p1ABAYE,
# p114-6
# p114-5
# p114-4
# p114-3
# p114-2
# p114-1
# pLeu,
# pLeu,
# pLeu,
# pLeu,
# pLeu,
# pTrp,
# pLeu,
# pTrp,
# pLeu-BCc,
# pBBp1,
# pUnnamed,
# unnamed1,
# unnamed,
# unnamed2,
# unnamed1,
# unnamed,
# pSAN1-1727,
# pKNA06,
# pKNA05,
# pKNA04,
# pKNA03,
# pKNA02,
# pKNA01,
# pRM10607,
# unnamed2,
# unnamed1,
# skipping ['Elizabethkingia', 'endophytica', 'strain', 'F3201', 'plasmid,', 'complete', 'sequence']
# pQpH1,
# pSTY1-1898,
# pEC244_1,
# pEC244_2,
# pEC244_KPC,
# pEC244_4,
# pECAZ159_1,
# pECAZ159_2,
# pEC517_1,
# pEC517_KPC,
# unnamed1,
# pEC656_1,
# pEC656_KPC,
# pEC276_1,
# pEC276_2,
# pEC276_3,
# pEC276_KPC,
# pEC881_1,
# pEC881_2,
# pEC881_KPC,
# pEC881_4,
# pEC881_5,
# pEC881_6,
# pEC881_7,
# pEC881_8,
# pEC422_1,
# pEC422_2,
# pEC422_KPC,
# pEC422_4,
# pEC545_1,
# pEC545_KPC,
# pEC545_3,
# pEC545_4,
# pEC545_5,
# pEC542_1,
# pEC542_KPC,
# pEC542_3,
# pEC542_4,
# pEC224_1,
# pEC224_2,
# pEC224_KPC,
# pEC224_4,
# pEC224_5,
# pEC224_6,
# pEC224_7,
# pEC224_8,
# pECAZ146_1,
# pECAZ146_KPC,
# pECAZ146_3,
# pECAZ146_4,
# pECAZ146_5,
# pECAZ146_6,
# pECAZ146_7,
# pDSK4,
# pDSK3,
# pDSK2,
# pDSK1,
# 8,
# 7,
# 6,
# 5,
# 4,
# 3,
# unnamed2,
# pUSA04-2-SUR11,
# pUSA04-1-SUR22,
# pUSA04-1-SUR17,
# pUSA04-1-SUR13,
# pUSA08-1-SUR15,
# pUSA07-1-SUR15,
# pUSA05-1-SUR15,
# pUSA04-1-SUR15,
# pUSA06-1-SUR10,
# pUSA05-1-SUR10,
# pUSA04-2-SUR10,
# pUSA01-1-SUR10,
# pSR04,
# pSR03,
# pSR02,
# pSR01,
# pUCI62,
# pUCI28,
# pCFSAN004175,
# skipping ['Staphylococcus', 'aureus', 'subsp.', 'aureus', 'isolate', 'Clinical', 'isolate', 'genome', 'assembly,', 'plasmid:', 'II']
# paadD,
# plinE154,
# pSARA13,
# pl2015TE24968,
# pNCCP14562,
# pNCCP14558,
# pV521,
# pSAN1-1735,
# pRM9437,
# pSTY3-1898,
# pSTY2-1898,
# pRIVM6519-2,
# pRIVM6519-1,
# pST20130939,
# pST20130940,
# pST20130938,
# pST20130943,
# skipping ['Staphylococcus', 'aureus', 'strain', 'NZAK3', 'genome', 'assembly,', 'plasmid:', '2']
# pMI
# pFDA209P
# skipping ['Staphylococcus', 'aureus', 'subsp.', 'aureus', 'strain', 'JS395', 'plasmid,', 'complete', 'sequence']
# pVR-MSSA_03,
# pVR-MSSA_02,
# pVR-MSSA_01,
# pRIVM1295-2,
# pRIVM1295-1,
# pRIVM1607,
# unnamed2,
# unnamed1,
# :
# :
# pCA12,
# pHUV05-03,
# pHUV05-02,
# pHUV05-01,
# pBe62,
# pGv88,
# pGv51,
# pV2200,
# pGR2B,
# pGR2A,
# pSA564,
# skipping ['Staphylococcus', 'aureus', 'subsp.', 'aureus', 'DSM', '20231', 'plasmid,', 'complete', 'sequence']
# skipping ['Staphylococcus', 'aureus', 'strain', 'RKI4', 'plasmid,', 'complete', 'genome']
# pCA15,
# pM121,
# pUSA500,
# skipping ['Staphylococcus', 'aureus', 'strain', '502A', 'plasmid,', 'complete', 'sequence']
# pS1945,
# pI6T6
# pI7S6
# pI1T1
# pI3T3
# unnamed2,
# unnamed1,
# pSSE-ATCC-43845,
# pATCC39184,
# pUSA02-ISMMS,
# pUSA01-ISMMS,
# pZ172_1,
# pZ172_2,
# skipping ['Staphylococcus', 'aureus', 'subsp.', 'aureus', '55/2053', 'plasmid,', 'complete', 'sequence']
# skipping ['Staphylococcus', 'aureus', 'CA-347', 'plasmid,', 'complete', 'sequence']
# pI8T7
# pI5S5
# pI4T8
# pLGA251
# pTW20_1
# skipping ['Staphylococcus', 'aureus', 'subsp.', 'aureus', 'TCH60', 'plasmid,', 'complete', 'sequence']
# pSaa6159,
# pAVX,
# pT181,
# pAVY,
# pUSA300HOUMR,
# pSJH101,
# pSJH901,
# pUSA03,
# pUSA02,
# pT181,
# pSAS,
# pN315
# VRSAp
# pPLP2,
# pPLP1,
# pJX1,
# pCFSAN004174,
# pCFSAN004173,
# pATCC10720,
# pLM5578,
# pCFSAN001297_01,
# pCFSAN001297_02,
# pFSIS1502916,
# pFSIS1502169,
# pCVM44454,
# pN55391,
# pCFSAN003890,
# pCFSAN001660,
# unnamed1,
# pSARB26_03,
# pSARB26_02,
# pSARB26_01,
# pSLT931,
# pESBL931,
# p931IncI2,
# p931IncI1,
# p931-3904,
# pSTY1-H2662,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Typhimurium', 'strain', 'NC983', 'plasmid,', 'complete', 'sequence']
# pAMR588-04-00318_99,
# pSH14-009_99,
# pAMR588-04-00435_37,
# pSH13-006_37,
# pAMR588-04-00320_99,
# pAMR588-04-00320_2,
# pSA01AB09084001_92,
# pSA01AB09084001_4,
# p09-036813-1A_42,
# p09-036813-1A_4,
# p09-036813-1A_3,
# p09-036813-1A_261,
# pCE-R2-11-0435_92,
# pCE-R2-11-0435_6,
# pCE-R2-11-0435_37,
# p11-004736-1-7_99,
# pSH14-028_6,
# pSH14-028_37,
# pSH14-028_2,
# pSA02DT09004001_101,
# unnamed1,
# small,
# intermediate,
# virulence,
# pSLT,
# unnamed2,
# unnamed2,
# unnamed1,
# pSTY1-2011K-1702,
# pSTY1-2010K-1587,
# pSTY1-2009K-1640,
# pSAN1-1736,
# pSAN1-2010K-2577,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Tennessee', 'strain', 'CFSAN001387', 'plasmid,', 'complete', 'sequence']
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Weltevreden', 'str.', '1655', 'plasmid,', 'complete', 'sequence']
# pSO3_STV,
# pYU15_94,
# pSO2_STV,
# pCFSAN010068_01,
# CFSAN023459_02,
# CFSAN023459_01,
# PDM05,
# PDM04,
# PDM03,
# PDM02,
# pN13-01290_98,
# pN13-01290_3-3,
# pN13-01290_3-1,
# pN13-01290_2,
# pN13-01290_23,
# pSA02DT10168701_99,
# pSA02DT10168701_37,
# p12-4374_96,
# p12-4374_62,
# p12-4374_3,
# p12-4374_37,
# p12-4374_2,
# :
# :
# :
# pCMCC50041,
# pLmN1546,
# :
# :
# pCFSAN001588_002,
# pCFSAN001588_001,
# pFORC7,
# p33676_4.5,
# p33673_IncF,
# p33676_IncA/C,
# pCFSAN000725_01,
# pCFSAN000679_01,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Enteritidis', 'str.', 'CDC_2010K_0968', 'plasmid00,', 'complete', 'sequence']
# D,
# C,
# B,
# A,
# A,
# E,
# D,
# C,
# B,
# A,
# D,
# C,
# B,
# A,
# F,
# E,
# D,
# C,
# B,
# A,
# D,
# C,
# B,
# A,
# B,
# A,
# C,
# B,
# A,
# C,
# B,
# A,
# A,
# A,
# D,
# C,
# B,
# A,
# B,
# A,
# B,
# A,
# A,
# A,
# E,
# D,
# C,
# B,
# A,
# A,
# B,
# A,
# B,
# A,
# B,
# A,
# A,
# B,
# A,
# A,
# pCFSAN000006,
# pYU39_2.7,
# pYU39_4.2,
# pYU39_4.8,
# pYU39_5.1,
# pYU39_IncX,
# pYU39_89,
# pYU39_IncA/C,
# pCFSAN000934_03,
# pCFSAN000934_02,
# pCVM22462,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Enteritidis', 'strain', 'Durban', 'plasmid,', 'complete', 'sequence']
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Enteritidis', 'strain', 'SEJ', 'plasmid,', 'complete', 'sequence']
# pCFSAN000111_01,
# pSLT_VNP20009,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Typhimurium', 'strain', '138736', 'plasmid,', 'complete', 'sequence']
# pSTY1,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Heidelberg', 'str.', 'CFSAN002064', 'plasmid,', 'complete', 'sequence']
# LM6179,
# pLMR479a,
# pCFSAN002069_02,
# pCFSAN002069_01,
# pDT104,
# RM1,
# pSEEH1578_03,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'Serovar', 'Cubana', 'str.', 'CFSAN002050', 'plasmid,', 'complete', 'sequence']
# unnamed,
# pSEEH1578_02,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'Serovar', 'Cubana', 'str.', 'CFSAN002050', 'plasmid,', 'complete', 'sequence']
# unnamed,
# unnamed,
# unnamed,
# pSEEH1578_01,
# pCFSAN001992_2,
# pCFSAN001992_1,
# pLM1-2cUG1
# pB182_37,
# p798_93,
# TY474p1,
# pSTUK-100,
# pSTMDT12_L
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Typhi', 'str.', 'P-stx-12', 'plasmid,', 'complete', 'sequence']
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Typhimurium', 'str.', '14028S', 'plasmid,', 'complete', 'sequence']
# pSTMDT12_S
# pLM1-2bUG1
# pLM5578,
# pCT02021853_74,
# skipping ['Salmonella', 'enterica', 'subsp.', 'enterica', 'serovar', 'Agona', 'str.', 'SL483', 'plasmid,', 'complete', 'sequence']
# pCVM19633_4,
# pCVM19633_110,
# pSL476_3,
# pSL476_91,
# pSL254_3,
# pSN254,
# pSC138,
# pSCV50,
# pLI100,
# B,
# A,
# A,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pEcoFMU07332d
# pEcoFMU073332c,
# pEcoFMU073332b
# pEcoFMU073332a,
# pMR0716_tem1,
# pMRSN346355_65.5,
# pMRSN346595_62.2,
# pMRSN346595_120.3,
# pMRSN346638_5.3,
# pMRSN346638_61.1,
# pMRSN346638_64.5,
# pMRSN346638_67.9,
# pMRSN346638_119.3,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pO157,
# pFORC31.4,
# pFORC31.3,
# pFORC31.2,
# pFORC31.1,
# pSLy21,
# pMS6198D,
# pMS6198C,
# pMS6198B,
# pMS6198A,
# pCFSAN004176G_02,
# pCFSAN004176P_01,
# pCFSAN004176P_03,
# p0157,
# unnamed5,
# unnamed4,
# unnamed3,
# unnamed2,
# unnamed1,
# pEC745_OXA48,
# pCFSAN004181P,
# pCFSAN004178P_02,
# pCFSAN004180G,
# pCFSAN004179G,
# pKpQIL-571,
# pECO-bc6,
# pNGF1_pCol_let_like,
# pNGF1_pCROD2_like,
# pS51_2,
# pS51_1,
# p0157,
# unnamed1,
# unnamed1,
# pOSAK1-WS4202,
# pO157-WS4202,
# pEC648_7,
# pEC648_6,
# pEC648_5,
# pEC648_4,
# pEC648_3,
# pEC648_2,
# pEC648_1,
# pHPLYSS1,
# pGS1191_1,
# skipping ['Jeotgalibaca', 'dankookensis', 'strain', 'EX-07', 'plasmid,', 'complete', 'sequence']
# pKPN-041,
# pNDM-1fa,
# pKPN-04f,
# unnamed2,
# unnamed1,
# pEC743_4,
# pEC743_3,
# pEC743_OXA48,
# pEC743_1,
# p28RC1,
# pSRCC
# pJJ1887-4,
# pJJ1887-5,
# pJJ1887-3,
# pJJ1887-2,
# pJJ1887-1,
# pZH063_2,
# pZH063_1,
# pSaT040,
# F128-(DHB4),
# F128-(C3026),
# KP-plasmid2,
# KP-plasmid1,
# pSF-468-5,
# pSF-468-4,
# pSF-468-3,
# pSF-468-2,
# pSF-468-1,
# pSF-166-1,
# skipping ['Escherichia', 'coli', 'strain', 'uk_P46212', 'plasmid,', 'complete', 'sequence']
# :
# :
# :
# :
# :
# pJJ2434_2,
# pJJ2434_1,
# pCD306,
# pSF-173-1,
# p1303_5,
# p1303_95,
# p1303_109,
# F,
# skipping ['Escherichia', 'coli', 'strain', 'CI5', 'plasmid,', 'complete', 'sequence']
# pEC958B,
# pEC958,
# p6409-202.186kb,
# pAPEC-O78-3,
# pAPEC-O78-2,
# pAPEC-O78-ColV,
# pECC-1470_100,
# skipping ['Escherichia', 'coli', 'ATCC', '25922', 'plasmid,', 'complete', 'sequence']
# skipping ['Escherichia', 'coli', 'ATCC', '25922', 'plasmid,', 'complete', 'sequence']
# p0157,
# pO104_H21,
# pO104_H7,
# p6409-151.583kb,
# pO145-12761,
# pRM12761,
# skipping ['Escherichia', 'coli', 'O157:H7', 'str.', 'EDL933', 'plasmid,', 'complete', 'sequence']
# pRM13516,
# pO145-13516,
# pSS17,
# p0157,
# p25155,
# p1ColV5155,
# pJJ1886_5,
# pJJ1886_4,
# pCR14_5,
# pCR14_4,
# pCR14_3,
# pCR14_2,
# pCR14_1,
# pKPGJ-3d,
# pKPGJ-3c,
# pKPGJ-3b,
# pKPGJ-3a,
# pKPGJ-2d,
# pKPGJ-2c,
# pKPGJ-2b,
# pKPGJ-2a,
# pKPGJ-1a,
# pKPGJ-1c,
# pKPGJ-1b,
# pCAV1752-278,
# pCAV1752-111,
# pCAV1752-5521,
# pCAV1752-4374,
# pCAV1752-3851,
# pKp1756,
# pCN1_2,
# pCN1_1,
# p35657-1,
# pKp_Goe_641-4,
# pKp_Goe_641-5,
# pKp_Goe_641-3,
# pKp_Goe_641-1,
# pKp_Goe_641-2,
# pKp_Goe_588-2,
# pKp_Goe_588-1,
# pCAV1042-183,
# pKPC_CAV1042-89,
# pKPC_CAV1042-44,
# pCAV1042-5566,
# pCAV1042-3223,
# pCAV1042-2781,
# pKp_Goe_070-3,
# pKp_Goe_070-2,
# pKp_Goe_070-1,
# pKp_Goe_629-2,
# pKp_Goe_629-1,
# pKp_Goe_414-6,
# pKp_Goe_414-5,
# pKp_Goe_414-4,
# pKp_Goe_414-3,
# pKp_Goe_414-1,
# pKp_Goe_414-2,
# pMNCRE78_3,
# pMNCRE78_1,
# unnamed,
# pKp_Goe_208-2,
# pKp_Goe_208-1,
# pMNCRE53_3,
# pMNCRE53_2,
# pMNCRE53_4,
# pMNCRE53_1,
# pKp_Goe_917-7,
# pKp_Goe_917-4,
# pKp_Goe_917-5,
# pKp_Goe_917-2,
# pKp_Goe_917-3,
# pKp_Goe_917-1,
# pKp_Goe_917-6,
# pKp_Goe_917-8,
# pMNCRE69_3,
# pMNCRE69_1,
# pMNCRE69_4,
# pMNCRE69_2,
# pCAV1453-208,
# pCAV1453-46,
# pCAV1453-14,
# pKQPS2,
# pKQPS1,
# pUCLAOXA232-6.X,
# pUCLAOXA232-5.X,
# pUCLAOXA232-4.X,
# pUCLAOXA232-3.X,
# pUCLAOXA232-6,
# pUCLAOXA232-5,
# pUCLAOXA232-4,
# pUCLAOXA232-3,
# pUCLAOXA232-2,
# pUCLAOXA232-1,
# pCAV1015-12,
# pCAV1015-76,
# pCAV1015-111,
# pCAV1015-114,
# pCAV1016-76,
# pCAV1016-90,
# pSg1-3,
# pSg1-2,
# pSg1-1,
# pSg1-NDM,
# unnamed2,
# unnamed1,
# 3,
# 2,
# 1,
# unamed,
# 3,
# 2,
# 1,
# unnamed2,
# unnamed1,
# pKpQIL-6e6,
# pKPN-fff,
# pKPN-821,
# pKPN-065,
# pKpQIL-9b8,
# pKPN-704,
# pKPN-332,
# pKV2,
# pKV1,
# skipping ['Escherichia', 'coli', 'ETEC', 'H10407', 'p58', 'plasmid']
# skipping ['Escherichia', 'coli', 'ETEC', 'H10407', 'p52', 'plasmid']
# skipping ['Escherichia', 'coli', 'ETEC', 'H10407', 'p948', 'plasmid']
# skipping ['Escherichia', 'coli', 'ETEC', 'H10407', 'p666', 'plasmid']
# pAA
# pRK1,
# pRK2,
# pABU,
# pCE10A,
# pCE10B,
# pCE10D,
# pCE10C,
# pRK1,
# pRK2,
# pUM146,
# pEKO1101,
# pEKO1102,
# pO26_4
# pO55,
# pECSF1
# pO26_1
# pO26_2
# pO26_3
# pO103
# pO157,
# pEFER,
# pSE11-1
# pSE11-3
# pSE11-2
# pSE11-6
# pSE11-5
# pSE11-4
# pEC4115,
# pO157,
# pAPEC-O1-ColBM,
# pAPEC-O1-R,
# pUTI89,
# pKPN-d6b,
# pKPN-d90,
# pKPN-7c3,
# pWSZBR,
# pKO_JKo3_4
# pKO_JKo3_3
# pKO_JKo3_2
# pKO_JKo3_1
# unnamed
# unnamed
# unnamed
# unnamed
# unnamed
# pKP1-19,
# pRJF999,
# pRJF293,
# unnamed2,
# unnamed1,
# 2,
# 1,
# p500_1420-13.838kb,
# p500_1420-51.662kb,
# p500_1420-130.552kb,
# pDMC1097-20.222kb,
# pDMC1097-77.775kb,
# pDMC1097-218.836kb,
# pUHKPC07-13.841kb,
# pUHKPC07-74.026kb,
# pUHKPC07-113.639kb,
# pUHKPC33-13.841kb,
# pUHKPC33-43.380kb,
# pUHKPC33-113.638kb,
# pUHKPC33-162.533kb,
# pCAV1335-115,
# pCAV1335-118,
# pCAV1335-92,
# pCAV1335-5410,
# pKPC_CAV1374,
# pCAV1374-228,
# pCAV1374-150,
# pCAV1374-84,
# pCAV1374-54,
# pCAV1374-49,
# pCAV1374-34,
# pCAV1374-16,
# pCAV1374-14,
# pCAV1374-6538,
# pCAV1374-1919,
# pCAV1099-114,
# pKPC_CAV1099,
# pCAV1099-111,
# pCAV1099-69,
# pCAV1099-5410,
# pCAV1344-250,
# pKPC_CAV1344,
# pCAV1344-78,
# pCAV1344-40,
# pCAV1344-3741,
# pKPC_CAV1596-97,
# pKPC_CAV1596-78,
# pCAV1596-41,
# pCAV1596-2927,
# pCAV1392-131,
# pCAV1392-50,
# pKPC_CAV1392,
# II,
# I,
# sequence
# sequence
# sequence
# skipping ['Klebsiella', 'pneumoniae', 'subsp.', 'pneumoniae', 'PittNDM01', 'plasmid3,', 'complete', 'sequence']
# skipping ['Klebsiella', 'pneumoniae', 'subsp.', 'pneumoniae', 'PittNDM01', 'plasmid2,', 'complete', 'sequence']
# skipping ['Klebsiella', 'pneumoniae', 'subsp.', 'pneumoniae', 'PittNDM01', 'plasmid1,', 'complete', 'sequence']
# pKPN-b0b,
# pKPN-a41,
# pKPN-262,
# pKPN-068,
# pKEC-dc3,
# pKP13f,
# pKP13e,
# pKP13d,
# pKP13a,
# pKP13c,
# pKP13b,
# plasmid1,
# plasmid2,
# pNJST258C1,
# pNJST258C3,
# pNJST258C2,
# pKPN-e44,
# pKPN-819,
# pKPC-484,
# pKPN-b9c,
# pPMK1-NDM,
# pPMK1-C,
# pPMK1-B,
# pPMK1-A,
# pKPN-498,
# pAAC154-a50,
# pKpQIL-531,
# pKPN-294,
# pKPN-c22,
# pKPN-852,
# pAAC154-a9e,
# pKPN-80a,
# pKPC-e4e,
# pKOXM1D,
# pKOXM1C,
# pKOXM1B,
# pKOXM1A,
# p34618-71.572kb,
# p34618-43.380kb,
# p34618-13.841kb,
# p34618-207.543kb,
# p2,
# p1,
# pKCTC2242,
# pKP187,
# pKP91,
# pKPN7,
# pKPN6,
# pKPN5,
# pKPN4,
# pKPN3,
# pK2044
# pG6809-1,
# pG6809-2,
# p92-9000,
# p628-KPC,
# pEC4365,
# pSLT,
# R388
# BPP5P1,
# pKPHS5,
# pECL_B,
# pECL_A,
# pYVe8081,
# pBT9727,
# pWCFS102,
# pWCFS101,
# pWCFS103,
# pDV,
# pO157,
# pAA-EA11,
# pG-EA11,
# pESBL-EA11,
# pO83_CORR,
# pKPHS6,
# pKPHS4,
# pKPHS2,
# pKPHS3,
# pKPHS1,
# lp28-1,
# lp17,
# lp21,
# pMESCI01,
# pBM407,
# pNGR234b,
# skipping ['Mycobacterium', 'abscessus', 'plasmid,', 'complete', 'sequence']
# Ti,
# pSMED01,
# pBOT3502,
# pSD197_spA,
# 1,
# pMP118,
# pSR35,
# unnamed,
# pSD1_197,
# pES100,
# pBClin15,
# pSF118-44,
# pSF118-20,
# pTT8,
# pTT27,
# pBFY46,
# pSE-12228-01,
# pSE-12228-02,
# pSE-12228-03,
# pSE-12228-04,
# pSE-12228-05,
# pSE-12228-06,
# pBLO1,
# pCP301,
# p5482,
# pTEF2,
# pTEF3,
# pTEF1,
# pDC3000B,
# pDC3000A,
# megaplasmid,
# SCP1,
# SCP2,
# pHCM2,
# pHCM1,
# pSymA,
# pSOL1,
# lp5,
# lp56,
# cp32-9,
# cp32-8,
# cp32-7,
# cp32-6,
# cp32-3,
# cp32-1,
# cp9,
# cp26,
# lp38,
# lp36,
# lp28-4,
# lp28-3,
# lp28-2,
# lp25,
# CP1,
# MP1,
# pLeu,
# pTrp,
# ece1,
# pMT1,
# pCD1,
# pPCP1,
# 1,
# pBMC401,
# 2,
# 3,
# pTF5,
# pFL1
# pKPS77,
# pKPoxa-48N2,
# pKHSB1
# pK1HV,
# pE66An,
# pRJF1,
# pIP1206,
# pMD136,
# skipping ['Plasmid', 'pADB201', '(from', 'Mycoplasma', 'mycoides),', 'complete', 'genome']
# pCTXM5-637,
# pKLH80,
# skipping ['Bifidobacterium', 'longum', 'pNAL8L', 'plasmid']
# skipping ['Bifidobacterium', 'longum', 'pNAL8M', 'plasmid']
# pMC-NDM,
# pSHK1,
# p1ABIBUN
# pKPS30,
# pCTXM5-1845,
# pCTXM5-1358,
# pCTXM5-891,
# pKp848CTX,
# pTDC-B
# pTDC-A
# pA85-3
# pSTm-A54650,
# p1643_10,
# p9134dT,
# p9134dAT,
# p9134,
# pYT3
# pS1400_89,
# skipping ['Arthrobacter', 'nicotinovorans', 'pAO1', 'megaplasmid', 'sequence,', 'strain', 'ATCC', '49919']
# pZM3H1,
# pP43BP4,
# pP109bwP1,
# pP60P1,
# pMWHK01,
# pRAY,
# pVPA3-1,
# ...
# pDB2011,
# pKP1780,
# pKPoxa-48N1,
# pCGB40,
# pCGS13,
# pCGS49,
# pLP5403,
# pLP5402,
# pLP5401,
# D,
# pCSA2,
# skipping ['Vibrio', 'parahaemolyticus', 'strain', 'v110', 'plasmid,', 'complete', 'sequence']
# pUR3912,
# pMARC4,
# pMARC3,
# pMARC2,
# pKP1433,
# pNDM102337,
# BRA100,
# pSinA,
# pKPX-2
# pKPX-1
# pQY431,
# pWG16,
# pWG13,
# pAhy2.5,
# skipping ['Enterobacter', 'cloacae', 'strain', 'M15', 'plasmid,', 'complete', 'sequence']
# pJEG012,
# pJEG011,
# pBHB,
# pSA737,
# pFiD188,
# pK18An,
# pSF301-3,
# pISP3
# pKPC-LK30,
# pB1000,
# pB1002,
# pBt1-3,
# pNDM-AB,
# pKPN5047,
# pAR6,
# pCTR,
# pYE315203,
# skipping ['Vibrio', 'coralliilyticus', 'strain', 'ATCC', 'BAA-450', 'plasmid,', 'complete', 'sequence']
# pNOR-2000,
# pDT4,
# pDPT3,
# 2s-pEI2,
# pEI3,
# pEI1,
# 19-pEI1,
# pEI1,
# pJIE186-2,
# pHN1122-1,
# pDT1
# pSTE1
# skipping ['Haemophilus', 'parainfluenzae', 'strain', '72322', 'plasmid,', 'complete', 'sequence']
# pCH91,
# pEST4011,
# pXF-RIV5,
# pMEC2,
# pB000b,
# pB000a,
# pB1024,
# pB1021,
# pB1019,
# pB1020,
# pB1023,
# pEC159,
# pB1018,
# pIG1,
# pBK31567,
# pNDM-OM,
# pBK31551,
# pMG2F-1,
# pMG1A-1,
# pMG2C-1,
# pMG2A-1,
# pMG1B-1,
# pMG2D-1,
# pMG2E-1,
# pMG2B-1,
# pMG1C-1,
# pWCZ,
# pNetB-NE10,
# pCpb2-CP1,
# pWBD3,
# pWBD1,
# pBFUK1,
# pWBD2,
# pNM11,
# pNM8,
# pOENI-1v2,
# pOENI-1,
# pEl1573,
# pKPN_CZ,
# pSB13,
# pKDO1,
# pHDC-I-9,
# pHDC-I-1,
# pRAY*-v2,
# pRAY*-v1,
# pZMN1-1,
# PML21,
# pKpS90,
# pR148,
# pIJB1,
# pTC2,
# p3M-2B,
# p3M-2A,
# p5580,
# pMARC5,
# pAES7,
# pSI01,
# pNDM-CIT,
# pMOS6,
# R830b,
# p96A29192-65,
# p14-120,
# pNCPPB880-40,
# pJ349-116,
# pJ337-114,
# pAC258-29,
# p40-95A,
# p14-95A,
# pPT14-32,
# pPDDCC3357-6,
# pJ353-116,
# pJ340-114,
# pJ340-69,
# pDFL14-10,
# pB76-81,
# pAC258-26,
# p3132-53,
# pR18,
# pMOS2,
# pDYM4.3k,
# pAES4,
# pHAE2,
# pMOS7,
# pMR68,
# pUR3937,
# pUR3036,
# pUCLAc,
# pUCLAa,
# pHW121,
# pHW120,
# pHW114B,
# pPLLHn-1,
# pHAE1,
# pAES2,
# pAES1,
# pINCan01,
# pWZ7140,
# pC1-1,
# pNDM-BJ02,
# pMMD,
# pPAB19-4,
# pP62BP1,
# pAES3,
# pVJL1,
# pYF27601,
# pNDM-BJ01,
# pRIO-5,
# pNB8c,
# pLME1,
# pAHH04,
# pRA0511,
# pMh1405,
# pCCK343,
# pHY,
# pGA2000,
# pSF301-1,
# pSF301-2,
# pTT0105,
# p09PLY-2,
# p05PLY-2,
# p09PLY-1,
# p08PLY-1,
# p05PLY-1,
# pS51B,
# pGL,
# pNC101,
# pDC09,
# pPCP1,
# pYV-WA314,
# pREN,
# pK2007C6,
# pK1002C2,
# pBHS24,
# pRF,
# pBMB2062-2,
# pBMB2062-56,
# cp26,
# pHW104,
# pHW66,
# pHW30076,
# pHW4594,
# pPHB194,
# pLJ42,
# pYC93,
# pWZ909,
# pEM1,
# pZMO1B,
# pB1000,
# pB1000,
# pHW114A,
# pHW42,
# pMMCU3,
# pLeu-Dn(USA1),
# pLeu-Dn(SAM),
# pJ612,
# pA1209,
# pLFH49,
# pLFS5,
# pLFH64,
# pPN223,
# pA1606,
# pB1000,
# pB1000',
# pB1000,
# pB1000,
# pB1000,
# pOYNIM_2002-2006,
# pOYNIM_1998-2000,
# EcOYNIM_2005,
# EcOYNIM_2002-2004,
# EcOYNIM_2000,
# EcOYNIM_1999,
# EcOYNIM_1998,
# pVV8,
# pAW153,
# p7313178-1,
# p9811071-1,
# unnamed,
# pOV,
# pLP712,
# pPDL2,
# pYS1,
# pSD118,
# pSG4,
# pSG53,
# pFZ51,
# pMBLR00,
# pAF22,
# pAF14,
# pAF12,
# pAF07,
# pAF04,
# pNE1280,
# pJV,
# pKV29,
# pIL6,
# pCQ4,
# pZMO7,
# pHH1107,
# pPR2,
# pBSDMV46A,
# pJIR3537,
# pJIR3843,
# pJIR3844,
# pLN126_33,
# pMO17_54,
# pVC,
# pHHV35,
# pHHV216,
# pUCLAb,
# pKLC102,
# pTSC1,
# pZMO1A,
# pSF5,
# pFP4,
# pKPN101-IT,
# pKP3-A,
# ColEST258,
# pIncX-SHV,
# pAAC154,
# pKpQIL-IT,
# pOXA-48,
# pNDM-KN,
# pSLMT,
# pRYCKPC3.1,
# pKKS49,
# pPM1,
# pUR4128,
# pUR5425,
# pUR2355,
# pMSA16,
# p9b,
# pCPS49,
# pCPS32,
# pDLK2,
# pDLK1,
# pIGMS32,
# pTR4,
# pNDM-HN380,
# pNDM10469,
# p18805-P03,
# p19321-P03,
# p18811-P01,
# p18811-P03,
# p19321-P01,
# p18809-P04,
# p18813-P03,
# p18810-P03,
# p18809-P03,
# p18808-P01,
# p18808-P03,
# p18807-P01,
# p18807-P03,
# p18806-P03,
# pASL01a,
# pAm08CQ3205,
# pAm08CD9902,
# pAm08CD7339,
# pAm08WL3069,
# pAm08CQ6130,
# pAm05WL6211,
# pAm05WL3325,
# pDKX1-TEM-52,
# pXZ,
# p417H-90,
# pLST424C-61,
# pLST424C-10,
# pHK23a,
# pGUE-NDM,
# pECY6-7,
# pPAB19-3,
# pPAB19-2,
# pZS50,
# pHCG11,
# pT108,
# pEC886,
# pEC34B,
# pEC34A,
# pEC158,
# pKST23,
# pHNDD81-1,
# pHK08,
# pHK09,
# pCERC1,
# pKST21,
# pNDM-HK,
# p838C-R1,
# pJD8,
# pCM959,
# pSYM1,
# Plm,
# pRPEC180_47,
# pKC396,
# pEC14_35,
# pHN7A8,
# pNDM10505,
# pE001,
# pAPEC1990_61,
# pPG010208,
# pPWD4_103,
# pQ1-1,
# pHK01,
# pNGX2-QnrS1,
# pNMEC31_31,
# pND12_96,
# pND11_107,
# pQNR2078,
# pO157,
# p62,
# pEAR5.2,
# pChi7122-2,
# pChi7122-3,
# pChi7122-4,
# pMUM003,
# 297_cp32-3,
# 297_cp32-11,
# 297_cp32-1,
# pWBG764,
# 297_lp28-4,
# 297_lp17,
# 297_lp38,
# 297_lp28-3,
# pSK67,
# 297_lp28-5,
# 297_lp28-1,
# 297_lp28-6,
# 297_lp36,
# SAP078A,
# 297_cp32-4,
# 297_cp26,
# 297_cp32-5,
# 297_cp32-7,
# SAP074A,
# 297_cp32-6,
# 297_cp32-9,
# 297_cp32-12,
# SAP048A,
# pHUSEC41-2,
# pTC1,
# pHUSEC41-3,
# pHUSEC41-4,
# pHUSEC41-1,
# pNDM-1_Dok01,
# pEA29,
# pEAR4.3,
# pWBG744,
# SAP077A,
# pWBG747,
# SAP104A,
# SAP065A,
# pWBG763,
# SAP095B,
# SAP094A,
# SAP093B,
# SAP093A,
# SAP089A,
# SAP085A,
# SAP084A,
# SAP078B,
# SAP073A,
# SAP072A,
# SAP070A,
# SAP053A,
# SAP051B,
# SAP051A,
# SAP050A,
# SAP049B,
# SAP049A,
# SAP046B,
# SAP046A,
# pWBG757,
# pWBG752,
# pWBG751,
# pWBG750,
# SAP015A,
# pPSED02,
# pSK11P,
# pSK11A,
# pSK11L,
# pRCEID2.9,
# 1,
# 2,
# pIL2,
# pBMB2062-4ac,
# pCCK411,
# pPI-1,
# pAQU1,
# pNDM-MAR,
# pI2,
# pR55,
# pTB30,
# pGL5
# pGL2
# pTS236,
# pRCEID7.6,
# pGL4
# pGL3
# pGL1
# pCfc1,
# pUUH239.1,
# pMR0211,
# pZB18,
# pUUH239.2,
# pKB1A97-67,
# pCG103-32,
# pAHH01,
# pAQ2-2,
# pES657-44,
# pAQ2-1,
# pPRH,
# pPSED02,
# pPSED02,
# pPABN1,
# KOPRI126573,
# pSSAP2,
# pKW2126,
# pSS-03,
# pXap41,
# pSRD77,
# pY0017,
# pHK17a,
# pKP1,
# R485
# pSY2,
# pIL1,
# pM7M2,
# pGB2001,
# pGB2002,
# pSM22,
# pRA0726,
# pRA0846,
# pSN22
# pVF22,
# pVF18,
# pVF50,
# pVF21,
# p271A,
# pIL7,
# pIL5,
# pIL4,
# pIL3,
# pGRT1,
# pNJAKD,
# pCPPB-1,
# pTML1
# N3,
# pR23,
# pHDC-RI
# pHDC-A
# pHDC-I
# pHDC-Tm,
# pHDC-HO,
# pBSDMV9,
# pEF-01,
# pRAM32,
# pBMB0558,
# pCWBFq,
# pECTm80,
# pWTY27,
# pSSAP1,
# VIBNI_pA,
# pKKS966,
# pS51A,
# pACK5,
# pc15-k,
# pLS20
# pLS32
# pPCP,
# pJARS36,
# pJARS35,
# pCD,
# pS177,
# pK50-2,
# pSD11,
# pPA43082
# p1B146,
# pAMI7,
# p3521,
# pLVP1401
# pCK41,
# pPHDD1,
# pBS-02,
# pJAM1
# pRCEID13.9,
# pRCEID3.2,
# p19,
# pGT231,
# pSM103mini,
# pKKS825,
# pCB42
# pEC_L8,
# pIR52-1,
# pSK1,
# pRSI13,
# RCFBPv3_mp,
# pLM33,
# pVAPAMBE116,
# pKC394,
# p1081,
# p557,
# pPAGA3
# pJA144188,
# pLAC1,
# pAL236-5,
# pAL236-2,
# pAL236-11,
# pPARG1,
# pBSG3,
# SAP108D,
# SAP106A,
# SAP104B,
# pLGV440,
# pAsa6,
# pSU1
# pBS-01,
# pRAM18,
# pKF3-140,
# pRAM23,
# pTXW,
# pACK3,
# pACK1,
# pSQ10,
# pSRD192,
# pPHDP10,
# pZZM405,
# pZZM402,
# pZZM401,
# pCGR2,
# pEG356
# pSM327,
# pRPSZY,
# pAL226,
# p11745,
# pPCZ2,
# pPCZ1,
# pPL1,
# pPZZ84,
# pSK11B,
# pC1,
# pAMI3,
# pAMbeta1,
# pMMCU2,
# pMbo4.6,
# pCQ3,
# pYS1,
# pZL12,
# pTSC2,
# pSK108,
# pSK103,
# pSK105,
# SAP108C,
# SAP108B,
# SAP108A,
# SAP018B,
# SAP018A,
# SAP110B,
# SAP110A,
# SAP107B,
# SAP107A,
# SAP106B,
# SAP105B,
# SAP105A,
# SAP045A,
# SAP020A,
# SAP016A,
# SAP008A,
# pSK76,
# SAP063A,
# pWBG754,
# SAP099B,
# pSK156,
# pSK62,
# SAP087A,
# SAP085B,
# SAP082A,
# SAP080A,
# SAP079A,
# SAP077B,
# SAP076A,
# SAP069A,
# SAP068A,
# SAP064A,
# SAP060B,
# SAP060A,
# SAP057A,
# SAP055A,
# SAP052A,
# SAP047A,
# pWBG759,
# pWBG758,
# pWBG753,
# pWBG749,
# pWBG746,
# pWBG745,
# SAP027A,
# pCM05,
# SAP019A,
# SAP017A,
# SAP014A,
# pI258,
# SAP012A,
# p5753cA,
# pAMI2,
# pVAE259,
# pEK516,
# 297_lp54,
# pF243,
# pF242,
# pLK39,
# pSLA2-L
# pRC18,
# pMMCU1,
# pACK4,
# pP9014
# pZY5,
# pABVA01,
# pCBM588
# pMP1,
# skipping ['Arcobacter', 'butzleri', 'strain', 'NCTC12481', 'plasmid,', 'complete', 'sequence']
# complete
# pNAH20,
# pFW213,
# pJALI,
# pCC3,
# pEC-IMP,
# pLB925A04,
# pLB925A03,
# pLB925A02,
# pLB925A01,
# pLD1,
# pC2C203U28
# pOYNIM,
# pOYM,
# EcOYW1,
# pSFKW33,
# pAPEC-1,
# ColE9-J,
# plLF82,
# pLgLA39,
# pCAR1.2,
# pLF24,
# pBD146,
# p6148,
# pECA1039,
# pUE30,
# skipping ['Yersinia', 'pseudotuberculosis', 'pGDT4', 'plasmid']
# pYC2,
# pRJ6,
# pTN38148,
# pRPCMY,
# p9701,
# p169,
# pBIFA24,
# pOR1,
# pCP8533etx,
# ICEhin1056,
# pEC01,
# pES213,
# 15S,
# pCC7,
# pB80,
# pO26-S3,
# pO26-S1,
# pVAPA1037,
# pVAPB1593,
# pLQ510,
# pBFP35,
# pAP3.9,
# pMBO-2,
# pMBO-1,
# pS4C,
# pA387,
# pCT14,
# pCNB,
# pTJ86-2,
# pTJ86-1,
# pCP4.2,
# pSdyT132,
# pBP68,
# pCPa,
# pSKPB18
# pTBBperi,
# pB21a,
# pCIBAO89,
# pYSI8,
# pDOJ1,
# pBMB175,
# pYMH5,
# p12494,
# pVCG4.1,
# pVCG1.2,
# pVCG1.1,
# pW240,
# pNL871104,
# pNL18.2,
# pNL14,
# pNL9,
# pNL3.2,
# pNL18.1,
# pHP666,
# pL4C,
# pCYLM01,
# pCYLM02,
# pXT107,
# pRA1,
# pXAG81,
# pAG1,
# pXAG82,
# pPASb11,
# pPAPh2,
# pCFV108,
# pASV479,
# pMA67,
# pSMQ-316,
# pEOC01,
# pNL7.1,
# pNL932024,
# pNL750149,
# pNL3.1,
# pNL11,
# pNL15,
# pSmeSM11b,
# pHP69,
# pOAD2
# pMEA100,
# pMSR0,
# pRi2659,
# pNSL1,
# pRL1,
# pRM,
# pBCXO1,
# pBC210,
# pCER270,
# pHB0503,
# pAK1,
# pSFn1,
# pILR091,
# pKW1,
# skipping ['Exiguobacterium', 'arabatum', 'pEspB', 'plasmid']
# skipping ['Exiguobacterium', 'arabatum', 'pEspA', 'plasmid']
# pKM19s,
# pHDC
# pTcM1,
# pKL0018
# pC194-like,
# R7K,
# pLR585,
# pLR581,
# pChr15,
# pSI-1,
# pHLHK22,
# pSM76,
# pGS18,
# pPaWBNy-2,
# pPaWBNy-1,
# pYE854,
# pLS55,
# pMF1,
# pTer331,
# pAV2,
# pAV1,
# pJS42,
# pJS33,
# pFR12,
# pFR12.5,
# pH205,
# MccC7-H22,
# pBl1,
# pSMA23,
# pADAP,
# pM4,
# p23023,
# pA1,
# pMV158,
# skipping ['Streptomyces', 'lavendulae', 'Miniplasmid', 'pSLG33,', 'complete', 'sequence']
# pKLCA,
# pLME108
# p9555,
# p9956,
# pLMO226,
# pLD-TEX-KL,
# pMTH1,
# pK214,
# pAK51
# skipping ['Vibrio', 'vulnificus', 'pC4602-2', 'plasmid']
# skipping ['Vibrio', 'vulnificus', 'pC4602-1', 'plasmid']
# pR99,
# skipping ['Actinobacillus', 'porcitonsillarum', 'pKMA202', 'plasmid']
# skipping ['Actinobacillus', 'porcitonsillarum', 'pKMA5', 'plasmid']
# skipping ['Actinobacillus', 'pleuropneumoniae', 'pARD3079', 'plasmid']
# pAb5S9,
# pQBR103,
# pLO2,
# pDBORO,
# pLEW279b,
# pLEW279a,
# pLEW6932,
# NR1,
# pLEW517,
# pLEW517,
# pNC500
# pTC68,
# pAM5,
# pL2,
# pMUR050,
# pMG828-1,
# pBP136
# DNA,
# pRE25,
# pSLS
# pDU1,
# pND324,
# pKKTET7,
# p9705,
# pCJ01,
# pLNU9
# skipping ['Staphylococcus', 'chromogenes', 'pLNU8', 'plasmid']
# skipping ['Streptococcus', 'pneumoniae', 'pSpnP1', 'plasmid']
# skipping ['Staphylococcus', 'simulans', 'pLNU5', 'plasmid']
# skipping ['Staphylococcus', 'haemolyticus', 'pLNU7', 'plasmid']
# R751,
# pCAR3
# pCIZ2,
# pYAN-2
# pYAN-1
# pHW15,
# pCJ1170,
# pCC2228-3,
# pCC2228-2,
# pCC2228-1,
# pUPTC237
# pLS30
# pKLCB,
# pRL2,
# pA1
# pCCK13698,
# pLNU4,
# pLNU1,
# pCPF5603,
# pLNU2,
# pLNU3,
# pMGT,
# skipping ['Staphylococcus', 'saprophyticus', 'pSES22', 'plasmid,', 'isolate', '44']
# pF8801,
# pHT
# skipping ['Streptomyces', 'venezuelae', 'pSVH1', 'plasmid']
# pSci6
# skipping ['Spiroplasma', 'citri', 'pSci5', 'plasmid']
# skipping ['Spiroplasma', 'citri', 'pSci4', 'plasmid']
# skipping ['Spiroplasma', 'citri', 'pSci3', 'plasmid']
# skipping ['Spiroplasma', 'citri', 'pSci2', 'plasmid']
# skipping ['Spiroplasma', 'citri', 'pSci1', 'plasmid']
# pSciA
# pPG01,
# pF1947,
# skipping ['orf', '{2-kbp', 'miniplasmid}', '[Bacillus', 'thuringiensis,', 'kurstaki', 'HD-3a3b,', 'Plasmid', 'Complete,', '2058', 'nt]']
# pAG6,
# pSG4,
# from
# from
# from
# from
# from
# pSP187
# pSW49,
# pSW174,
# p3386,
# pTet,
# p3384,
# skipping ['Actinobacillus', 'porcitonsillarum', 'pKMA757', 'plasmid']
# skipping ['Actinobacillus', 'porcitonsillarum', 'pKMA1467', 'plasmid']
# skipping ['Actinobacillus', 'porcitonsillarum', 'pIMD50', 'plasmid']
# skipping ['Actinobacillus', 'porcitonsillarum', 'pKMA505', 'plasmid']
# pBJS-O,
# pPSAS1522
# skipping ['Actinobacillus', 'pleuropneumoniae', 'pKMA2425', 'plasmid']
# pMU1,
# pBC1,
# p47S,
# p47L,
# pSM19035,
# pCL300,
# pACK6,
# pNL01,
# pBL63.1
# p49879.1,
# pMR2,
# p49879.2,
# unknown,
# pFP1,
# pFP11,
# skipping ['Bacillus', 'mycoides', 'pDx14.2', 'plasmid']
# pSTE2,
# skipping ['Bacillus', 'mycoides', 'pSin9.7', 'plasmid']
# pSRD191,
# pSIO1,
# pBMBt1,
# pSx-Qyy,
# pA81,
# pIH01,
# pBS608,
# pHLHK8,
# pNO33
# pRKU1,
# pMOL28,
# pMOL30,
# pSKU146,
# pBRG1
# pRE8424
# pYIT356
# pFR18,
# pFBAOT6,
# pTet,
# pCC31,
# pE194,
# pRH45II,
# pBLTVA-1,
# pAlvB,
# pPMA4326B,
# pPMA4326A,
# pRA2,
# pBLTVA-2,
# pAlvA,
# pPMA4326E,
# pPMA4326C,
# pPMA4326D,
# pKAP298,
# pAL202,
# pANL,
# pEA29,
# pLME106,
# pBMYdx
# skipping ['Bacillus', 'mycoides', 'pBMY1', 'plasmid']
# pTXL1
# pZMO2,
# pEMCJH03,
# pCD6,
# pBM19,
# pNAD1,
# pFL5,
# pMS260,
# pKB1
# pFL7,
# pLG,
# pXcB,
# p250,
# pEU30,
# pEL60,
# pAP2,
# pPI-2
# pUB101,
# pUO1,
# skipping ['Staphylococcus', 'sciuri', 'pSCFS1', 'plasmid,', 'complete', 'sequence']
# pBD2,
# pQBR55
# pLW043,
# skipping ['Corynebacterium', 'striatum', 'strain', 'M82B', 'R-plasmid', 'pTP10,', 'complete', 'sequence']
# pVT2,
# pNG2,
# pDP1,
# pSMB1,
# pMW2,
# pBI143,
# pYVe8081,
# pYQ39,
# pVir,
# pCJ419,
# pEsp1396,
# pEN2701,
# pSD20,
# pSD10,
# p121BS,
# pPS1M3
# pPS41,
# pADP-1,
# pHT926
# pWC1,
# pCJ84,
# pCI411,
# pLL1212,
# pCLP,
# pSV2,
# skipping ['Corynebacterium', 'glutamicum', 'strain', 'ATCC31830', 'R-plasmid', 'pCG4,', 'complete', 'sequence']
# pXZ608,
# pKC5b,
# pRV500,
# pLA106
# pNB2,
# pPL7065,
# pAH82,
# pBL1,
# pBM02,
# pUH24,
# pMa025,
# pONE429
# pONE430
# pJW1,
# pFN1,
# pTLC,
# pAP12875,
# pXV64,
# pFNL10,
# pHel4
# pHel5
# cp18-2,
# pMN5,
# pB264,
# pREAT701,
# pN42
# pJBL2
# pHP003,
# pHPM8,
# pBPS1,
# pCD1,
# pPCP1,
# pCD1,
# pMT1,
# pEJ30,
# pSMB74,
# pPNWB,
# pCP1,
# pNAC1,
# PNAC2,
# pA501,
# pA505,
# pJR2,
# pJR1,
# pHP51,
# pJS-B,
# pTC-F14
# pS7b,
# pSD25,
# pLME300
# pGA2,
# pCG2,
# pAG3,
# skipping ['Lactobacillus', 'reuteri', 'endogenous', 'plasmid,', 'complete', 'sequence']
# skipping ['Leuconostoc', 'citreum', 'pLC22R', 'plasmid,', 'complete', 'genome']
# pMG160
# 1,
# pAG5
# pB44,
# pEP36,
# pCAR1,
# pEA2.8,
# p9L,
# skipping ['Aeromonas', 'salmonicida', 'subsp.', 'salmonicida', 'pAsal3', 'plasmid']
# skipping ['Aeromonas', 'salmonicida', 'subsp.', 'salmonicida', 'pAsal2', 'plasmid']
# skipping ['Aeromonas', 'salmonicida', 'subsp.', 'salmonicida', 'pAsal1', 'plasmid']
# pGI1,
# pTX14-2,
# skipping ['Bartonella', 'grahamii', 'pBGR2', 'cryptic', 'plasmid']
# pDR1-1,
# pDR1-1B,
# pWKS1,
# pUIBI-1,
# pF3028,
# pSepCH,
# Rts1
# pFAJ2600
# pMGD2,
# p4M,
# pTE44,
# pB85766,
# pJHCMW1,
# pLA103
# pK64,
# skipping ['Mannheimia', 'varigena', 'MVSCS1', 'plasmid']
# pGO128,
# extrachromosomal
# 2
# pTET3
# pNGA2,
# pRS2,
# pRAS3.1,
# pTYM1,
# pRAS3.2,
# pCRP3,
# pCRL1127,
# pKH9,
# ColJs,
# pSD15,
# pCRL291.1,
# pSRQ700,
# pK43,
# pER13,
# pAC450,
# pFKN,
# pCD4,
# pFQ12,
# pWR501,
# pA01
# skipping ['Histophilus', 'somni', 'small', 'plasmid,', 'complete', 'sequence']
# pTS1,
# DN1
# pPvu1,
# pRGO1,
# p545,
# pIE1115,
# pCpA1,
# pTA144
# pEI2,
# pEI1,
# pPZG500,
# pUCD5000,
# pNL1,
# skipping ['Clostridium', 'sp.', 'MCF-1', 'indigenous', 'plasmid,', 'complete', 'sequence']
# pLJ1,
# pAYL
# pAYS
# sequence
# pRM21,
# pBMB2062,
# pPF1,
# pLUG10,
# phytoplasma
# pBG7AU,
# pJV1,
# pSA1.1,
# pSCL,
# p103,
# unknown,
# pXZ10142,
# skipping ['Corynebacterium', 'glutamicum', 'strain', '22243', 'R-plasmid', 'pAG1,', 'complete', 'sequence']
# pAM330
# pXZ10145.1,
# pSR1,
# LIM,
# pCIBb1,
# pAP1,
# pAP1,
# pGT232,
# pLTK2,
# pLH1,
# pLBB1,
# pWS58,
# pTX14-1,
# pTX14-3,
# p1414,
# pTA1060,
# pTA1015,
# pTA1040,
# pSTK1
# pPL10,
# pXO2,
# PX01,
# pPL1,
# pCI305,
# pCIS3,
# pAH33,
# pGB3634,
# pGB354,
# pSSU1
# pSK6,
# pSK3,
# J3358,
# pBAW301,
# pPBS1,
# pMA4
# pMA2
# pSR1,
# complete
# pPA52,
# pOM1,
# QpDV,
# QpH1,
# pO3K6
# pSA19
# pZMO1,
# pJD4,
# pTA144
# pAC5,
# pRi1724
# pPT1,
# pOM1,
# pHPM186,
# pHPO100,
# pHP489,
# pHPM180,
# pLeu-Sg,
# pVT745,
# F
# pNZ4000,
# R100
# P9
# RSF1010,
# pBC16,
# pT48,
# pT181,
# pNS1,
# pNE131,
# pIP404,
# pIJ101,
# pUB110,
# pNKH43,
# pAL5000,
# pLS1,
# pKYM,
# pJD1,
# pIM13,
# ColA,
# pCHL1,
# ColE1,
# pWVO2,
# PB1000,
# pTW9,
# p75,
# pRW35,
# pGR7,
# pLPI8,
# pETN48,
# pLGUG1,
# unnamed,
# pWZ1668,
# pCT,
# pEC_Bactec,
# pEC_L46,
# pEC_B24,
# pPS1,
# pNL194,
# IncQ-type
# pKP048,
# p746,
# pKOX105,
# pKKS627,
# pDK1,
# pXF-RIV19,
# pXF-RIV11,
# pEP5289,
# pSJ2-8,
# pKpQIL,
# pDLK3,
# pKF3-94,
# pXY3,
# pAR141,
# pEC14-9,
# pAH3680,
# pO26-CRL,
# pPM18,
# pPR9,
# pColE1-H22,
# pBORa53,
# pleu-BTg,
# pSmeSM11a,
# pCD02,
# pCD01,
# pKF3-70,
# pLP2140,
# pBEE99,
# pEntH10407,
# pMAS2027,
# pMMA2,
# pW2,
# pEC14_114,
# pEK499,
# pEK204,
# pVir68,
# pRAx,
# pRA1,
# pColE8,
# pAR060302,
# peH4H,
# pHN61,
# pLFE1,
# pSW2,
# pSW5,
# pEC-IMPQ,
# pGO1,
# pO26-Vir,
# pB1006,
# pB1005,
# pYe4449-2,
# pYe4449-1,
# pRS5,
# pCHE-A,
# pAPEC-O103-ColBM,
# pO26-L,
# pBMB7635,
# p5217,
# pECOED,
# 55989p,
# pMG2200,
# pKpn114,
# pCTXM360,
# pKP96,
# pVGA,
# pKL001,
# pCmGFP,
# pC221,
# pLP2111,
# pEC278,
# pIGMS31,
# pIGRK,
# 12,
# 9,
# pCCK1900,
# pMG1,
# pZMO1,
# pO26-S4,
# pBRST7.6,
# pIP816,
# pFI2576,
# pLR1,
# pMyBK1,
# pLTK13,
# p6043A,
# pVEF3,
# pK245,
# pMA3,
# pNP40,
# pRA3,
# pColG,
# pIGRW12,
# pFRL1,
# p6043B,
# pEF1,
# pK29,
# pIGWZ12,
# pIGMS5,
# pSJ5.2,
# pCW3,
# pMAR7,
# pTiBo542,
# pRK10,
# pMET-1,
# pMM1,
# pKH21,
# pKH19,
# pKH20,
# pKH12,
# pWBG1773,
# pTZ2162,
# pKH14,
# pKH15,
# pKH13,
# pABIR,
# pVM01,
# pOLA52,
# pRI1,
# pKH17,
# pV030-8,
# pFR55,
# pUCH-1,
# pW2580,
# pKH16,
# pDN281,
# pTZ4,
# p09022A,
# p0908,
# PPC1,
# pBtoxis,
# EDINA,
# skipping ['Zymomonas', 'mobilis', 'subsp.', 'mobilis', 'ATCC', '10988', 'unknown', 'plasmid,', 'complete', 'sequence']
# pIGJC156,
# pMATVIM-7,
# pSFO157,
# pGdh442,
# skipping ['Magnetospirillum', 'gryphiswaldense', 'MSR-1', 'plasmid,', 'complete', 'sequence']
# pYR1,
# pK1S1,
# pVEF2,
# pVEF1,
# pP99-018,
# pP91278,
# pVI678,
# pCL2.1,
# pMG828-5,
# pMG828-4,
# pMG828-3,
# pMG828-2,
# pO86A1,
# skipping ['Borrelia', 'burgdorferi', 'strain', 'Ip21', 'plasmid,', 'complete', 'sequence']
# pLNU6,
# pBS228,
# pBMB9741,
# pCF10,
# pWW53,
# pSA1379,
# pSA1308,
# NAH7,
# pCPF4969,
# pAPEC-O2-ColV,
# pCoo,
# pO113,
# pAgK84,
# pWBG738,
# pFMBL1,
# pDAN-involved,
# pTF62,
# Rms149,
# pMG1,
# pCCK381,
# pCCK3259,
# pOM1,
# pColK-K235,
# pMAC,
# pIL105,
# pCCK647,
# pTB6,
# pHS-Rec,
# pHS-Tet,
# pAPEC-O2-R,
# pJB01,
# pPB1,
# pCTX-M3,
# pG8786,
# p256,
# pDN571,
# pFL129,
# pTT8,
# pGI3,
# pSK639,
# pSN2,
# pS194,
# p29807,
# pSMQ173b,
# pSMQ308,
# pC15-1a,
# p9123,
# pC223,
# pLVPK,
# pJM1,
# pIGAL1,
# R478,
# pPSR1,
# pt38,
# pRUM,
# pAMalpha1,
# pEF1071,
# pSK41,
# pKH3,
# pKPN2,
# pIP843,
# pLG13,
# p1658/97,
# pDTG1,
# pKJ50,
# pMD5057,
# pSRQ800,
# pSRQ900,
# pER371,
# pSMQ172,
# pEA1.7,
# pRm1132f,
# lp16.9,
# pF3031,
# pNAC3,
# pND103,
# pS7a,
# pYVa127/90,
# pNVH01,
# pIS2,
# pLP9000,
# pLP2000,
# pMLU1,
# pWW0,
# pETB,
# pRS3,
# pLM7,
# p2457TS2,
# pUA140,
# pMHSCS1,
# pKJ36,
# pAM373,
# pKlebB-k17/80,
# pMRC01,
# pCFC2,
# pCFC1,
# pXF868,
# pER36,
# pER35,
# p21,
# pC221,
# pKH7,
# pKH6,
# pC194,
# pMD136,
# pIG1,
# pYC,
# pYVe227,
# R721,
# pKL1,
# pCol-let,
# CloDF13,
# pECO29,
# Ti,
# pTi-SAKURA,
# pMBCP,
# pJTPS1,
# pPP81,
# pLeu-Dn,
# pC30il,
# pWV01,
# pTiC58,
# 718

# %%
# We can see that most of the entries in the list are what we want but not all
# so for now we will perform the FIRST ORDER FILTERING by removing all the single length entries

plasmid_list = [x[:-1] for x in plasmids if len(x) > 1]
print(plasmid_list[258:262])
# Out:
# ['pRi_26-59', 'pTi_CFBP2788', 'pTi_Tun198', 'pTi_CFBP5767']

# %%
# Testing the code

test_plasmids = plasmid_list[258:262]

for i in range(len(test_plasmids)):
  each_plasmid = str(test_plasmids[i])
  email_id = each_plasmid + '@gmail.com'
  print(f"Query running for {each_plasmid}. ({i+1}/{len(test_plasmids)})")
  plasmid_data(each_plasmid,email_id)
# Out:
# Query running for pRi_26-59. (1/4)
# Folder made for pRi_26-59
# pRi_26-59 Rhizobium rhizogenes strain 26-59 plasmid pRi_26-59, complete sequence
# DataFrame made for pRi_26-59 at /content/pRi_26-59/NZ_KY000033
# pRi_26-59 Rhizobium rhizogenes strain 26-59 plasmid pRi_26-59, complete sequence
# The dataset does not contain all the values
# Query running for pTi_CFBP2788. (2/4)
# Folder made for pTi_CFBP2788
# pTi_CFBP2788 Agrobacterium fabrum strain CFBP2788 plasmid pTi_CFBP2788, complete sequence
# DataFrame made for pTi_CFBP2788 at /content/pTi_CFBP2788/NZ_KY000032
# pTi_CFBP2788 Agrobacterium fabrum strain CFBP2788 plasmid pTi_CFBP2788, complete sequence
# The dataset does not contain all the values
# Query running for pTi_Tun198. (3/4)
# Folder made for pTi_Tun198
# pTi_Tun198 Agrobacterium fabacearum strain Tun198 plasmid pTi_Tun198, complete sequence
# DataFrame made for pTi_Tun198 at /content/pTi_Tun198/NZ_KY000031
# pTi_Tun198 Agrobacterium fabacearum strain Tun198 plasmid pTi_Tun198, complete sequence
# The dataset does not contain all the values
# Query running for pTi_CFBP5767. (4/4)
# Folder made for pTi_CFBP5767
# pTi_CFBP5767 Agrobacterium fabacearum strain CFBP5767 plasmid pTi_CFBP5767, complete sequence
# DataFrame made for pTi_CFBP5767 at /content/pTi_CFBP5767/NZ_KY000030
# pTi_CFBP5767 Agrobacterium fabacearum strain CFBP5767 plasmid pTi_CFBP5767, complete sequence
# The dataset does not contain all the values

# %%
# Running the code for the first 100 plasmids in the list

batches = [plasmid_list[i:i+100] for i in range(0,len(plasmid_list),100)]
print(f"Total batches: {len(batches)}")
i = 0
for each_batch in batches:
  print(f"Processing batch {i+1}/{len(batches)}.............")
  j = 0
  for each_plasmid in each_batch:
    each_plasmid = str(each_plasmid)
    email_id = each_plasmid + '@gmail.com'
    print(f"Query running for {each_plasmid}. ({j+1}/{len(each_batch)})")
    plasmid_data(each_plasmid,email_id)
    j += 1
  i += 1
# Out:
# Total batches: 130
# Processing batch 1/130.............
# Query running for p186-KPC. (1/100)
# Folder made for p186-KPC
# p186-KPC Aeromonas taiwanensis strain L186 plasmid p186-KPC, complete sequence
# DataFrame made for p186-KPC at /content/p186-KPC/NZ_MH624130
# p186-KPC Aeromonas taiwanensis strain L186 plasmid p186-KPC, complete sequence
# DataFrame made for p186-KPC at /content/p186-KPC/MH624130
# Query running for pEC07. (2/100)
# Folder made for pEC07
# pEC07 Acinetobacter sp. Res13-Abat-PEC07-P2-02 map unlocalized plasmid unnamednovel_0 unnamednovel_0_tig57, whole genome shotgun sequence
# pEC07 Acinetobacter sp. Res13-Abat-PEC07-P2-02 seq_tig1, whole genome shotgun sequence
# Query running for p838B-R. (3/100)
# Folder made for p838B-R
# p838B-R Escherichia coli strain 838B plasmid p838B-R, complete sequence
# DataFrame made for p838B-R at /content/p838B-R/NZ_MH618673
# p838B-R Escherichia coli strain 838B plasmid p838B-R, complete sequence
# The dataset does not contain all the values
# p838B-R Escherichia coli plasmid p838B-R transposon Tn2, complete sequence
# The dataset does not contain all the values
# Query running for pMO. (4/100)
# Folder made for pMO
# pMO Escherichia coli strain MO plasmid pMO, complete sequence
# DataFrame made for pMO at /content/pMO/NZ_MG886288
# pMO Hydrogenobaculum sp. Y04AAS1 chromosome, complete genome
# pMO Lactiplantibacillus plantarum strain PMO08 plasmid pPMO190, complete sequence
# DataFrame made for pPMO190 at /content/pMO/NZ_CP062061
# pMO Lactiplantibacillus plantarum strain PMO08 plasmid pPMO500, complete sequence
# DataFrame made for pPMO500 at /content/pMO/NZ_CP062060
# pMO Klebsiella pneumoniae strain AM100_PMO_1D_9A AM100_PMO_1D_9A.Scaf4, whole genome shotgun sequence
# pMO Lactiplantibacillus plantarum strain PMO08 plasmid pPMO190, complete sequence
# DataFrame made for pPMO190 at /content/pMO/CP062061
# pMO Lactiplantibacillus plantarum strain PMO08 plasmid pPMO500, complete sequence
# DataFrame made for pPMO500 at /content/pMO/CP062060
# pMO Mucilaginibacter paludis DSM 18603 chromosome, whole genome shotgun sequence
# pMO Methanolacinia petrolearia DSM 11571 chromosome, complete genome
# pMO Escherichia coli strain MO plasmid pMO, complete sequence
# The dataset does not contain all the values
# pMO Natranaerobius thermophilus JW/NM-WN-LF plasmid pNTHE02, complete sequence
# pMO Luteimicrobium xylanilyticum strain HY-24 chromosome, complete genome
# pMO Caldithrix abyssi DSM 13497 chromosome, whole genome shotgun sequence
# pMO Calothrix sp. PCC 7507 chromosome, complete genome
# pMO Sulfuricurvum kujiense DSM 16994 chromosome, complete genome
# pMO Arcobacter nitrofigilis DSM 7299 chromosome, complete genome
# pMO Catenulispora acidiphila DSM 44928 chromosome, complete genome
# pMO Pelodictyon phaeoclathratiforme BU-1 chromosome, complete genome
# pMO Rubinisphaera brasiliensis DSM 5305 chromosome, complete genome
# pMO Cellulophaga algicola DSM 14237 chromosome, complete genome
# pMO Hyphomicrobium denitrificans ATCC 51888 chromosome, complete genome
# pMO Desulfocurvibacter africanus subsp. africanus str. Walvis Bay chromosome, complete genome
# pMO Desulfatibacillum aliphaticivorans strain AK-01, complete genome
# pMO Photobacterium damselae subsp. piscicida DNA, chromosome: 1, complete genome
# pMO Acetomicrobium hydrogeniformans ATCC BAA-1850 strain OS1 A_hydrogeniformans-1.0.1_Cont0.1, whole genome shotgun sequence
# pMO Bacillus subtilis subsp. subtilis strain SRCM101384 contig00004, whole genome shotgun sequence
# pMO Parageobacillus thermoglucosidasius C56-YS93 plasmid pGEOTH01, complete sequence
# pMO Dokdonia sp. 4H-3-7-5 chromosome, complete genome
# pMO Acetivibrio thermocellus DSM 1313 chromosome, complete genome
# pMO [Clostridium] saccharolyticum WM1 chromosome, complete genome
# pMO Sediminispirochaeta smaragdinae DSM 11293 chromosome, complete genome
# pMO Nitrosococcus watsonii C-113 chromosome, complete genome
# pMO Thermincola potens JR chromosome, complete genome
# pMO Ruminiclostridium cellulolyticum H10 chromosome, complete genome
# pMO Thioalkalivibrio sulfidiphilus HL-EbGr7 chromosome, complete genome
# pMO Methanosphaerula palustris E1-9c chromosome, complete genome
# pMO Acetivibrio thermocellus ATCC 27405 chromosome, complete genome
# pMO Sulfobacillus thermosulfidooxidans DSM 9293 genome assembly, contig: Contig1, whole genome shotgun sequence
# pMO Rubrobacter radiotolerans DSM 5868 genome assembly, contig: Contig12, whole genome shotgun sequence
# pMO Peptoniphilus asaccharolyticus DSM 20463 genome assembly, contig: Pasa20463_Contig222, whole genome shotgun sequence
# pMO Thermanaeromonas toyohensis ToBE genome assembly, chromosome: I
# pMO Paenibacillus nuruki strain TI45-13ar contig00027, whole genome shotgun sequence
# pMO Glaciecola sp. 4H-3-7+YE-5 plasmid pGLAAG01, complete sequence
# pMO Rhizobium leguminosarum bv. trifolii WSM2304 plasmid pRLG201, complete sequence
# pMO Ruminococcus albus 7 plasmid pRUMAL03, complete sequence
# pMO Ruminococcus albus 7 plasmid pRUMAL01, complete sequence
# pMO Marivirga tractuosa DSM 4126 plasmid pFTRAC01, complete sequence
# pMO Ilyobacter polytropus DSM 2926 plasmid pILYOP02, complete sequence
# pMO Ilyobacter polytropus DSM 2926 plasmid pILYOP01, complete sequence
# pMO Halomicrobium mukohataei DSM 12286 plasmid pHmuk01, complete sequence
# pMO Halanaerobium praevalens DSM 2228, complete genome
# pMO Bacteroides ovatus strain KLE1656 Bacteroides_spHMPREF2532-1.0_Cont38.1, whole genome shotgun sequence
# pMO Christensenella minuta strain DSM 22607 genomic scaffold Scaffold234, whole genome shotgun sequence
# pMO Christensenella minuta strain DSM 22607 HMPREF3293-1.0_Cont129.1, whole genome shotgun sequence
# pMO Methanobacterium lacus strain AL-21, complete genome
# pMO Ruminococcus albus 7, complete genome
# pMO Oceanithermus profundus DSM 14977, complete genome
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig0, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig2, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig3, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig4, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig5, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig6, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig8, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig9, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig11, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig12, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig13, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig15, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig27, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 genomic scaffold FDUTEX481_Contig37, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig0.4, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig0.5, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig0.7, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig2.2, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig3.4, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig4.3, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig5.1, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig5.5, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig6.6, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig8.4, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig9.4, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig11.10, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig12.1, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig13.10, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig15.2, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig27.1, whole genome shotgun sequence
# pMO Tolypothrix sp. PCC 7601 strain UTEX B 481 FDUTEX481_Contig37.1, whole genome shotgun sequence
# pMO Enterococcus faecium 13.SD.W.09 genomic scaffold Scaffold263, whole genome shotgun sequence
# pMO Enterococcus casseliflavus 14-MB-W-14 genomic scaffold Scaffold347, whole genome shotgun sequence
# pMO Leptonema illini DSM 21528 genomic scaffold Lepilscaffold_1, whole genome shotgun sequence
# pMO Clostridium sp. DL-VIII chromosome, whole genome shotgun sequence
# pMO Enterococcus faecalis TX0470 genomic scaffold Scfld237, whole genome shotgun sequence
# pMO Enterococcus faecalis TX0312 genomic scaffold Scfld30, whole genome shotgun sequence
# pMO Enterococcus faecalis TX0109 genomic scaffold Scfld92, whole genome shotgun sequence
# pMO Enterococcus faecalis TX2137 genomic scaffold Scfld555, whole genome shotgun sequence
# pMO Enterococcus faecalis TX0102 genomic scaffold Scfld206, whole genome shotgun sequence
# pMO Enterococcus faecalis TX1342 genomic scaffold Scfld258, whole genome shotgun sequence
# pMO Enterococcus faecalis TX1302 genomic scaffold Scfld52, whole genome shotgun sequence
# pMO Enterococcus faecalis TX0031 genomic scaffold Scfld153, whole genome shotgun sequence
# Query running for pECPB39. (5/100)
# Folder made for pECPB39
# pECPB39 Escherichia coli strain ECPB39 plasmid pECPB39, complete sequence
# DataFrame made for pECPB39 at /content/pECPB39/NZ_MG886287
# pECPB39 Escherichia coli strain ECPB39 plasmid pECPB39, complete sequence
# DataFrame made for pECPB39 at /content/pECPB39/MG886287
# Query running for pECSIC9. (6/100)
# Folder made for pECSIC9
# pECSIC9 Escherichia coli strain ECSIC9 plasmid pECSIC9, complete sequence
# DataFrame made for pECSIC9 at /content/pECSIC9/NZ_MG886286
# pECSIC9 Escherichia coli strain ECSIC9 plasmid pECSIC9, complete sequence
# DataFrame made for pECSIC9 at /content/pECSIC9/MG886286
# Query running for p1107-IncFIC. (7/100)
# Folder made for p1107-IncFIC
# Query running for p1107-99K. (8/100)
# Folder made for p1107-99K
# p1107-99K Escherichia coli strain 1107 plasmid p1107-99K, complete sequence
# The dataset does not contain all the values
# p1107-99K Escherichia coli strain 1107 plasmid p1107-99K, complete sequence
# The dataset does not contain all the values
# Query running for p974-IncF. (9/100)
# Folder made for p974-IncF
# p974-IncF Escherichia coli strain 974 plasmid p974-IncF, complete sequence
# DataFrame made for p974-IncF at /content/p974-IncF/NZ_MH580300
# p974-IncF Escherichia coli strain 974 plasmid p974-IncF, complete sequence
# DataFrame made for p974-IncF at /content/p974-IncF/MH580300
# Query running for pCFJY-17. (10/100)
# Folder made for pCFJY-17
# pCFJY-17 Citrobacter freundii strain JY-17 plasmid pCFJY-17, complete sequence
# DataFrame made for pCFJY-17 at /content/pCFJY-17/NZ_MH763829
# pCFJY-17 Citrobacter freundii strain JY-17 plasmid pCFJY-17, complete sequence
# The dataset does not contain all the values
# Query running for pKPC45a. (11/100)
# Folder made for pKPC45a
# pKPC45a Klebsiella pneumoniae strain KPC45 plasmid pKPC45a, complete sequence
# DataFrame made for pKPC45a at /content/pKPC45a/NZ_MH595534
# pKPC45a Klebsiella pneumoniae strain KPC45 plasmid pKPC45a, complete sequence
# DataFrame made for pKPC45a at /content/pKPC45a/MH595534
# Query running for pKPN535a. (12/100)
# Folder made for pKPN535a
# pKPN535a Klebsiella pneumoniae strain KPN535 plasmid pKPN535a, complete sequence
# DataFrame made for pKPN535a at /content/pKPN535a/NZ_MH595533
# pKPN535a Klebsiella pneumoniae strain KPN535 plasmid pKPN535a, complete sequence
# DataFrame made for pKPN535a at /content/pKPN535a/MH595533
# Query running for pWBG615. (13/100)
# Folder made for pWBG615
# pWBG615 Staphylococcus aureus strain WG1647 plasmid pWBG615, complete sequence
# DataFrame made for pWBG615 at /content/pWBG615/NZ_MH587578
# pWBG615 Staphylococcus aureus strain WG1647 plasmid pWBG615, complete sequence
# DataFrame made for pWBG615 at /content/pWBG615/MH587578
# Query running for pWBG707. (14/100)
# Folder made for pWBG707
# pWBG707 Staphylococcus aureus strain WBG10513 plasmid pWBG707, complete sequence
# DataFrame made for pWBG707 at /content/pWBG707/NZ_MH587577
# pWBG707 Staphylococcus aureus strain WBG7410 plasmid pWBG707, complete sequence
# DataFrame made for pWBG707 at /content/pWBG707/NZ_KX149097
# pWBG707 Staphylococcus aureus strain WBG10513 plasmid pWBG707, complete sequence
# DataFrame made for pWBG707 at /content/pWBG707/MH587577
# pWBG707 Staphylococcus aureus strain WBG7410 plasmid pWBG707, complete sequence
# DataFrame made for pWBG707 at /content/pWBG707/KX149097
# Query running for pWBG14. (15/100)
# Folder made for pWBG14
# pWBG14 Staphylococcus aureus strain WG512 plasmid pWBG14, complete sequence
# DataFrame made for pWBG14 at /content/pWBG14/NZ_MH587576
# pWBG14 Staphylococcus aureus strain WG512 plasmid pWBG14, complete sequence
# DataFrame made for pWBG14 at /content/pWBG14/MH587576
# Query running for pWBG637. (16/100)
# Folder made for pWBG637
# pWBG637 Staphylococcus aureus strain WBG4880 plasmid pWBG637, complete sequence
# DataFrame made for pWBG637 at /content/pWBG637/NZ_MH587575
# pWBG637 Staphylococcus aureus strain WBG1024 plasmid pWBG637, complete sequence
# DataFrame made for pWBG637 at /content/pWBG637/NZ_KX086582
# pWBG637 Staphylococcus aureus strain WBG4880 plasmid pWBG637, complete sequence
# DataFrame made for pWBG637 at /content/pWBG637/MH587575
# pWBG637 Staphylococcus aureus strain WBG1024 plasmid pWBG637, complete sequence
# DataFrame made for pWBG637 at /content/pWBG637/KX086582
# Query running for pWBG731. (17/100)
# Folder made for pWBG731
# pWBG731 Staphylococcus aureus strain WBG10514 plasmid pWBG731, complete sequence
# DataFrame made for pWBG731 at /content/pWBG731/NZ_MH587574
# pWBG731 Staphylococcus aureus strain WBG10514 plasmid pWBG731, complete sequence
# DataFrame made for pWBG731 at /content/pWBG731/MH587574
# Query running for pYUI-1. (18/100)
# Folder made for pYUI-1
# pYUI-1 Pseudomonas aeruginosa strain PA-IMP-1 plasmid pYUI-1, complete sequence
# DataFrame made for pYUI-1 at /content/pYUI-1/NZ_MH594579
# pYUI-1 Pseudomonas aeruginosa strain PA-IMP-1 plasmid pYUI-1, complete sequence
# The dataset does not contain all the values
# Query running for pIBACIncN. (19/100)
# Folder made for pIBACIncN
# pIBACIncN Citrobacter freundii strain AA535 plasmid pIBACIncN, complete sequence
# DataFrame made for pIBACIncN at /content/pIBACIncN/NZ_MH536949
# pIBACIncN Citrobacter freundii strain AA535 plasmid pIBACIncN, complete sequence
# The dataset does not contain all the values
# Query running for pJN05NDM7. (20/100)
# Folder made for pJN05NDM7
# pJN05NDM7 Escherichia coli strain JN05 plasmid pJN05NDM7, complete sequence
# DataFrame made for pJN05NDM7 at /content/pJN05NDM7/NZ_MH523639
# pJN05NDM7 Escherichia coli strain JN05 plasmid pJN05NDM7, complete sequence
# The dataset does not contain all the values
# Query running for pBP-6322. (21/100)
# Folder made for pBP-6322
# pBP-6322 Bacillus altitudinis strain 63-2-2 plasmid pBP-6322, complete sequence
# DataFrame made for pBP-6322 at /content/pBP-6322/NZ_CP069099
# pBP-6322 Bacillus altitudinis strain 63-2-2 plasmid pBP-6322, complete sequence
# DataFrame made for pBP-6322 at /content/pBP-6322/CP069099
# Query running for pBP-33.4. (22/100)
# Folder made for pBP-334
# pBP-33.4 Bacillus safensis strain 33.4 plasmid pBP-33.4, complete sequence
# DataFrame made for pBP-33.4 at /content/pBP-334/NZ_CP106653
# pBP-33.4 Bacillus safensis strain 33.4 plasmid pBP-33.4, complete sequence
# DataFrame made for pBP-33.4 at /content/pBP-334/CP106653
# Query running for pBP-33-3. (23/100)
# Folder made for pBP-33-3
# pBP-33-3 Bacillus pumilus strain 33-3 plasmid pBP-33-3, complete sequence
# DataFrame made for pBP-33-3 at /content/pBP-33-3/NZ_MH539888
# pBP-33-3 Bacillus pumilus strain 33-3 plasmid pBP-33-3, complete sequence
# The dataset does not contain all the values
# Query running for pBP-MRL1. (24/100)
# Folder made for pBP-MRL1
# pBP-MRL1 Bacillus pumilus strain MRL1 plasmid pBP-MRL1, complete sequence
# DataFrame made for pBP-MRL1 at /content/pBP-MRL1/NZ_MH522715
# pBP-MRL1 Bacillus pumilus strain MRL1 plasmid pBP-MRL1, complete sequence
# The dataset does not contain all the values
# Query running for PWA8. (25/100)
# Folder made for PWA8
# PWA8 Escherichia coli strain WA8 plasmid pWA8, complete sequence
# DataFrame made for pWA8 at /content/PWA8/NZ_MG773378
# PWA8 Acinetobacter baumannii strain PWa8_3139 NODE_83_length_49302_cov_35.806040, whole genome shotgun sequence
# PWA8 Escherichia coli strain WA8 plasmid PWA8, complete sequence
# The dataset does not contain all the values
# Query running for pTH. (26/100)
# Folder made for pTH
# pTH Campylobacter jejuni strain S2-20 chromosome, complete genome
# pTH Vibrio parahaemolyticus strain TW01 chromosome 1, complete sequence
# pTH Vibrio parahaemolyticus strain M0904 chromosome 1, complete sequence
# pTH Limosilactobacillus reuteri strain MD IIE-43 chromosome, complete genome
# pTH Dickeya fangzhongdai strain LCCT2-1 chromosome, complete genome
# pTH Bifidobacterium longum subsp. longum strain BG-L47 chromosome, complete genome
# pTH Paramuribaculum intestinale strain DSM 100764 chromosome, complete genome
# pTH Enterococcus faecalis strain V386 NODE_7_length_92546_cov_49.900778, whole genome shotgun sequence
# pTH Salmonella enterica strain LSP 38/19 NODE_24_length_192377_cov_43.697983, whole genome shotgun sequence
# pTH Salmonella enterica strain LSP 40/19 NODE_14_length_192193_cov_43.522312, whole genome shotgun sequence
# pTH [Ruminococcus] gnavus strain NBRC 114413 chromosome, complete genome
# pTH Enterococcus faecalis strain V359 NODE_7_length_92546_cov_35.967442, whole genome shotgun sequence
# pTH Enterococcus casseliflavus strain V308 NODE_10_length_94405_cov_39.320987, whole genome shotgun sequence
# pTH Enterococcus casseliflavus strain V311 NODE_10_length_94405_cov_40.605804, whole genome shotgun sequence
# pTH Enterococcus faecalis strain V392 NODE_4_length_290115_cov_10.611760, whole genome shotgun sequence
# pTH Streptomyces libani subsp. rufus strain NBRC 15424 chromosome
# pTH Salmonella sp. S13 chromosome, complete genome
# pTH Salmonella sp. HNK130 chromosome, complete genome
# pTH Agrobacterium tumefaciens strain CFBP6626 chromosome circular, complete sequence
# pTH Bacteroides sp. AM25-34 AM25-34.Scaf1, whole genome shotgun sequence
# pTH Bacteroides sp. AM22-3LB AM22-3LB.Scaf6, whole genome shotgun sequence
# pTH Anoxybacillus flavithermus strain DSM 2641T chromosome, complete genome
# pTH Streptomyces lydicus strain GS93 isolate 23 chromosome, complete genome
# pTH Streptomyces glaucescens strain GLA.O, complete genome
# pTH Bacillus methanolicus MGA3, complete genome
# pTH Streptococcus macedonicus ACA-DC 198, complete sequence
# pTH Clostridium sp. SS2/1 Scfld_03_19, whole genome shotgun sequence
# pTH Rickettsia felis URRWXCal2, complete sequence
# pTH Aeromonas enteropelogenes VA118 DNA, complete genome
# pTH Aeromonas enteropelogenes VA111 DNA, complete genome
# pTH Aeromonas veronii VA60 DNA, complete genome
# pTH Aeromonas veronii VA7 DNA, complete genome
# pTH Staphylococcus aureus strain SA328 chromosome, complete genome
# pTH Klebsiella quasipneumoniae strain 2023CB-00436 chromosome, complete genome
# pTH Staphylococcus aureus strain SA1197 chromosome, complete genome
# pTH Pseudomonas aeruginosa strain 2021CK-01337 chromosome, complete genome
# pTH Staphylococcus aureus strain SA575 chromosome, complete genome
# pTH Klebsiella pneumoniae strain 2022JQ-00762 chromosome, complete genome
# pTH Klebsiella pneumoniae strain 2022JQ-00839 chromosome, complete genome
# pTH Klebsiella pneumoniae strain 2023JQ-00099 chromosome, complete genome
# pTH Segatella copri strain HDE06 chromosome, complete genome
# pTH Prevotella hominis strain HDD12 chromosome, complete genome
# pTH Xanthomonas hortorum pv. pelargonii strain 22-331 chromosome, complete genome
# pTH Xanthomonas dyei strain 22-325 chromosome, complete genome
# pTH Xanthomonas hortorum pv. pelargonii strain 22-324 chromosome, complete genome
# pTH Xanthomonas hortorum pv. pelargonii strain 22-322 chromosome, complete genome
# pTH Xanthomonas hortorum pv. pelargonii strain 22-315 chromosome, complete genome
# pTH Campylobacter jejuni strain S2-20 chromosome, complete genome
# pTH Vibrio parahaemolyticus strain M0904 chromosome 1, complete sequence
# pTH Vibrio parahaemolyticus strain TW01 chromosome 1, complete sequence
# pTH Citrobacter freundii isolate FELIX_MS689 chromosome, complete genome
# pTH Escherichia coli isolate FELIX_MS772 chromosome, complete genome
# pTH Escherichia coli isolate FELIX_MS771 chromosome, complete genome
# pTH Escherichia coli strain HNSQ2209 chromosome, complete genome
# pTH Proteus mirabilis strain PM32 chromosome, complete genome
# pTH Pseudomonas fluorescens strain FDAARGOS_1088 chromosome, complete genome
# pTH Pseudomonas marginalis strain LMG 17761 Ga0074679_14, whole genome shotgun sequence
# pTH Streptomyces rochei strain 7434AN4 chromosome
# pTH Pseudomonas fluorescens FH5 scf_29078_74.1_contig_1, whole genome shotgun sequence
# pTH Gardnerella vaginalis 409-05, complete sequence
# pTH Helicobacter pylori strain HP18045 1, whole genome shotgun sequence
# pTH Streptomyces violaceoruber strain CGMCC 4.1801 chromosome, complete genome
# pTH Mutant Bacillus subtilis isolate FELIX_MS886, complete genome
# pTH Mutant Escherichia coli isolate FELIX_MS772, complete genome
# pTH Mutant Escherichia coli isolate FELIX_MS771, complete genome
# pTH Mutant Citrobacter freundii isolate FELIX_MS689, complete genome
# pTH Mutant Citrobacter freundii isolate FELIX_MS690, complete genome
# pTH Qipengyuania sp. SS22 chromosome, complete genome
# pTH Klebsiella pneumoniae strain KPTA-2108 chromosome, complete genome
# pTH Pseudomonas aeruginosa strain R31 chromosome, complete genome
# pTH Dickeya fangzhongdai strain NHT-1 chromosome, complete genome
# pTH Pseudomonas aeruginosa strain CUVET18-860 chromosome, complete genome
# pTH Pseudomonas aeruginosa strain CUVET20-956 chromosome, complete genome
# pTH Pseudomonas aeruginosa strain CUVET21-397 chromosome, complete genome
# pTH Escherichia coli isolate F60 genome assembly, contig: contig1, whole genome shotgun sequence
# pTH Escherichia coli isolate F14 genome assembly, contig: contig3, whole genome shotgun sequence
# pTH Escherichia coli isolate F848 genome assembly, contig: contig2, whole genome shotgun sequence
# pTH Aeromonas sp. CD chromosome, complete genome
# pTH Mutant Serratia marcescens isolate MES-4 (30-8), complete genome
# pTH Serratia marcescens strain MES-4 chromosome
# pTH Aeromonas sp. XH chromosome, complete genome
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S213 S213_contig_00014, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S350 S350_contig_00015, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S395 S395_contig_00015, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S133 S133_contig_00013, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S173 S173_contig_00015, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S224 S224_contig_00002, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S131 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S273 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S808 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S750 Utg1236_polypolish, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S156 S156_contig_00003, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S114 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S155 S155_contig_00002, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S218 S218_contig_00009, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S465 S465_contig_00004, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S161 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S661 S661_contig_00014, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S204 1, whole genome shotgun sequence
# pTH Salmonella enterica subsp. enterica serovar Enteritidis strain S379 1, whole genome shotgun sequence
# Query running for pM518-OXA18. (27/100)
# Folder made for pM518-OXA18
# Query running for pM517-OXA18. (28/100)
# Folder made for pM517-OXA18
# Query running for pM513-OXA18. (29/100)
# Folder made for pM513-OXA18
# Query running for pM324-NDM. (30/100)
# Folder made for pM324-NDM
# pM324-NDM Enterobacter hormaechei subsp. xiangfangensis strain M324 plasmid pM324-NDM1, complete sequence
# DataFrame made for pM324-NDM1 at /content/pM324-NDM/NZ_AP018835
# pM324-NDM Enterobacter hormaechei subsp. xiangfangensis M324 plasmid pM324-NDM1 DNA, complete sequence
# The dataset does not contain all the values
# Query running for pM321-NDM. (31/100)
# Folder made for pM321-NDM
# pM321-NDM Klebsiella pneumoniae strain M321 plasmid pM321-NDM1, complete sequence
# DataFrame made for pM321-NDM1 at /content/pM321-NDM/NZ_AP018834
# pM321-NDM Klebsiella pneumoniae M321 plasmid pM321-NDM1 DNA, complete sequence
# The dataset does not contain all the values
# Query running for pM309-NDM. (32/100)
# Folder made for pM309-NDM
# pM309-NDM Escherichia coli strain M309 plasmid pM309-NDM5, complete sequence
# DataFrame made for pM309-NDM5 at /content/pM309-NDM/NZ_AP018833
# pM309-NDM Escherichia coli M309 plasmid pM309-NDM5 DNA, complete sequence
# The dataset does not contain all the values
# Query running for pM308-NDM. (33/100)
# Folder made for pM308-NDM
# pM308-NDM Enterobacter hormaechei subsp. xiangfangensis strain M308 plasmid pM308-NDM1, complete sequence
# DataFrame made for pM308-NDM1 at /content/pM308-NDM/NZ_AP018832
# pM308-NDM Enterobacter hormaechei subsp. xiangfangensis M308 plasmid pM308-NDM1 DNA, complete sequence
# The dataset does not contain all the values
# Query running for pM206-OXA18. (34/100)
# Folder made for pM206-OXA18
# Query running for pM206-NDM. (35/100)
# Folder made for pM206-NDM
# pM206-NDM Enterobacter hormaechei subsp. xiangfangensis strain M206 plasmid pM206-NDM1, complete sequence
# DataFrame made for pM206-NDM1 at /content/pM206-NDM/NZ_AP018830
# pM206-NDM Enterobacter hormaechei subsp. xiangfangensis strain M206 plasmid pM206-OXA181, complete sequence
# pM206-NDM Enterobacter hormaechei subsp. xiangfangensis M206 plasmid pM206-OXA181 DNA, complete sequence
# pM206-NDM Enterobacter hormaechei subsp. xiangfangensis M206 plasmid pM206-NDM1 DNA, complete sequence
# The dataset does not contain all the values
# Query running for pLz4W. (36/100)
# Folder made for pLz4W
# pLz4W Pseudomonas sp. Lz4W plasmid pLz4W, complete sequence
# DataFrame made for pLz4W at /content/pLz4W/NZ_MF768471
# pLz4W Pseudomonas sp. Lz4W plasmid pLz4W, complete sequence
# The dataset does not contain all the values
# Query running for pJMUB303. (37/100)
# Folder made for pJMUB303
# pJMUB303 Pseudomonas marginalis ICMP 11289 scaffold19, whole genome shotgun sequence
# pJMUB303 Vibrio cholerae strain 964015 NODE_4_length_210473_cov_247.769811, whole genome shotgun sequence
# pJMUB303 Campylobacter jejuni strain S2-20 plasmid pCJABK49, complete sequence
# pJMUB303 Campylobacter jejuni strain S2-20 chromosome, complete genome
# pJMUB303 Vibrio parahaemolyticus strain TW01 plasmid pVPTW014, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain TW01 plasmid pVPTW013, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain TW01 plasmid pVPTW012, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain TW01 plasmid pVPTW011, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain TW01 chromosome 1, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09047, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09046, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09045, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09044, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09043, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09042, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 plasmid pVPM09041, complete sequence
# pJMUB303 Vibrio parahaemolyticus strain M0904 chromosome 1, complete sequence
# pJMUB303 Vibrio sp. Vb2899 NODE_23_length_59738_cov_115.500645, whole genome shotgun sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073F, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073H, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073G, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073E, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073D, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073C, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073B, complete sequence
# pJMUB303 Lactococcus cremoris strain UC073 plasmid pUC073A, complete sequence
# pJMUB303 Limosilactobacillus reuteri strain MD IIE-43 plasmid pLR-MDIIE43-2, complete sequence
# pJMUB303 Limosilactobacillus reuteri strain MD IIE-43 plasmid pLR-MDIIE43-1, complete sequence
# pJMUB303 Limosilactobacillus reuteri strain MD IIE-43 chromosome, complete genome
# pJMUB303 Acinetobacter baumannii strain ABO21-A049 plasmid pABO21-A049-4, complete sequence
# pJMUB303 Acinetobacter baumannii strain ABO21-A049 plasmid pABO21-A049-3, complete sequence
# pJMUB303 Acinetobacter baumannii strain ABO21-A049 plasmid pABO21-A049-2, complete sequence
# pJMUB303 Acinetobacter baumannii strain ABO21-A049 plasmid pABO21-A049-1, complete sequence
# pJMUB303 Providencia sp. D4759 plasmid pD4759_2_2, complete sequence
# pJMUB303 Providencia sp. D4759 plasmid pD4759_2_1, complete sequence
# pJMUB303 Dickeya fangzhongdai strain LCCT2-1 chromosome, complete genome
# pJMUB303 Enterobacter kobei strain ATCC BAA-260, whole genome shotgun sequence
# pJMUB303 Enterobacter kobei strain JCM 8580 map unlocalized plasmid pJCM_8580, whole genome shotgun sequence
# pJMUB303 Bacillus cereus strain GUCC 3 plasmid plas4, complete sequence
# pJMUB303 Bacillus cereus strain GUCC 3 plasmid plas3, complete sequence
# pJMUB303 Bacillus cereus strain GUCC 3 plasmid plas2, complete sequence
# pJMUB303 Bacillus cereus strain GUCC 3 plasmid plas1, complete sequence
# pJMUB303 Escherichia coli strain GCEC19 plasmid pGCEC19, complete sequence
# pJMUB303 Bifidobacterium longum subsp. longum strain BG-L47 chromosome, complete genome
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed7, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed6, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed5, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed4, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed3, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed2, complete sequence
# pJMUB303 Priestia megaterium strain EA208 plasmid unnamed1, complete sequence
# pJMUB303 Bacillus sp. T3 plasmid unnamed, complete sequence
# pJMUB303 Bacillus subtilis strain N3378-3At plasmid pN3378-3At.1, complete sequence
# pJMUB303 Paramuribaculum intestinale strain DSM 100764 chromosome, complete genome
# pJMUB303 Enterobacter cloacae isolate IMP48, whole genome shotgun sequence
# pJMUB303 Raoultella ornithinolytica strain 170602815 plasmid p602815-CTXM, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 170602815 plasmid p602815-tet, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 170602815 plasmid p602815-KPC, complete sequence
# pJMUB303 Raoultella planticola strain 208355 plasmid p208355-NR, complete sequence
# pJMUB303 Raoultella planticola strain 208355 plasmid p208355-IMP, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 24150 plasmid p24150-NR, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 24150 plasmid p24150-tet, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 24150 plasmid p24150-arr, complete sequence
# pJMUB303 Raoultella ornithinolytica strain 24150 plasmid p24150-KPC, complete sequence
# pJMUB303 Salmonella enterica subsp. enterica serovar Dublin strain 03EB8736SAL isolate 03EB8736SAL, whole genome shotgun sequence
# pJMUB303 Salmonella enterica subsp. enterica serovar Dublin strain 03EB8736SAL isolate 03EB8736SAL, whole genome shotgun sequence
# pJMUB303 Salmonella enterica strain LSP 237/15 NODE_147_length_1705_cov_6.774072, whole genome shotgun sequence
# pJMUB303 Salmonella enterica strain LSP 237/15 NODE_82_length_574_cov_72.220528, whole genome shotgun sequence
# pJMUB303 Pseudomonas amygdali strain 35-1 plasmid p3, complete sequence
# pJMUB303 Pseudomonas amygdali strain 35-1 plasmid p2, complete sequence
# pJMUB303 Pseudomonas amygdali strain 35-1 plasmid p1, complete sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK29 NODE_15_length_87641_cov_38.3605, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK26 NODE_24_length_49097_cov_34.4872, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK27 NODE_90_length_4787_cov_25.8092, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK27 NODE_88_length_5317_cov_45.499, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDHK19 NODE_70_length_8987_cov_11.0158, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK33 NODE_86_length_4705_cov_12.7108, whole genome shotgun sequence
# pJMUB303 Klebsiella pneumoniae strain SDWK33 NODE_81_length_5464_cov_15.2393, whole genome shotgun sequence
# pJMUB303 Gluconobacter oxydans strain NRRL B-58 NODE_8_length_142213_cov_58.281998, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386, whole genome shotgun sequencing project
# pJMUB303 Enterococcus faecalis strain V386 NODE_28_length_309_cov_251.763736, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_27_length_318_cov_101.596859, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_26_length_359_cov_78.146552, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_25_length_392_cov_0.735849, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_24_length_404_cov_0.895307, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_23_length_476_cov_0.710602, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_22_length_478_cov_246.424501, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_21_length_616_cov_85.108384, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_20_length_670_cov_83.657459, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_19_length_801_cov_133.817507, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_18_length_1067_cov_70.093617, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_17_length_1083_cov_100.989540, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_16_length_1093_cov_98.900621, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_15_length_1124_cov_90.389168, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_14_length_1128_cov_228.857143, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_13_length_1578_cov_176.852516, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_12_length_1704_cov_194.280279, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_11_length_17703_cov_158.667103, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_10_length_32943_cov_131.392339, whole genome shotgun sequence
# pJMUB303 Enterococcus faecalis strain V386 NODE_9_length_53641_cov_49.163415, whole genome shotgun sequence
# Query running for pOSUKPC4. (38/100)
# Folder made for pOSUKPC4
# pOSUKPC4 Enterobacter hormaechei subsp. xiangfangensis strain OSUKPC4_L plasmid pOSUKPC4, complete sequence
# DataFrame made for pOSUKPC4 at /content/pOSUKPC4/NZ_CP024910
# pOSUKPC4 Enterobacter hormaechei subsp. xiangfangensis strain OSUKPC4_L plasmid pOSUKPC4, complete sequence
# DataFrame made for pOSUKPC4 at /content/pOSUKPC4/CP024910
# Query running for pRM9872-1. (39/100)
# Folder made for pRM9872-1
# pRM9872-1 Escherichia coli O145 str. RM9872 plasmid pRM9872-1, complete sequence
# DataFrame made for pRM9872-1 at /content/pRM9872-1/NZ_CP028380
# pRM9872-1 Escherichia coli O145 str. RM9872 plasmid pRM9872-1, complete sequence
# DataFrame made for pRM9872-1 at /content/pRM9872-1/CP028380
# Query running for unnamed3. (40/100)
# Folder made for unnamed3
# unnamed3 Priestia megaterium strain EA208 plasmid unnamed3, complete sequence
# The dataset does not contain all the values
# unnamed3 Staphylococcus epidermidis strain NBRC 113846 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP084011
# unnamed3 Halostella pelagica strain DL-M4 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP040681
# unnamed3 Klebsiella quasipneumoniae strain 2023CB-00436 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137439
# unnamed3 Klebsiella pneumoniae strain 2022JQ-00762 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137448
# unnamed3 Klebsiella pneumoniae strain 2022JQ-00839 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137453
# unnamed3 Klebsiella pneumoniae strain 2023JQ-00099 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137458
# unnamed3 Escherichia coli strain HNTH2207 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137724
# unnamed3 Escherichia coli strain HNSQ2209 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137740
# unnamed3 Lacticaseibacillus paracasei strain CAUH35 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP012190
# unnamed3 Rhizobium leguminosarum bv. trifolii CB782 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP007070
# unnamed3 Escherichia coli strain HNTH2207 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137724
# unnamed3 Photobacterium damselae subsp. piscicida strain AS-16-0555-7 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP061866
# unnamed3 Comamonas thiooxydans strain CSUSB4 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083941
# unnamed3 Escherichia coli strain NDM6 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083870
# unnamed3 Escherichia coli strain NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083875
# unnamed3 Escherichia coli strain NDM2 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083887
# unnamed3 Escherichia coli strain NDM1 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083891
# unnamed3 Escherichia coli strain NDM3 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083883
# unnamed3 Klebsiella pneumoniae strain KP101_SE2_14.23_ST147_NDM5_OXA232 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137415
# unnamed3 Klebsiella pneumoniae strain KP119_WM3_21.23_ST147_NDM1 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137398
# unnamed3 Klebsiella pneumoniae strain KP39_L11_43.22_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137387
# unnamed3 Klebsiella pneumoniae strain KP51_L9_46.22_ST147_NDM1_OXA48 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137385
# unnamed3 Klebsiella pneumoniae strain KP82_L15_04.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137431
# unnamed3 Klebsiella pneumoniae strain KP88_L3_06.23_ST147_NDM14 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137430
# unnamed3 Klebsiella pneumoniae strain KP97_L17_12.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137361
# unnamed3 Klebsiella pneumoniae strain KP102_WM3_17.23_ST147_OXA181 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137410
# unnamed3 Klebsiella pneumoniae strain KP124_L5_21.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137394
# unnamed3 Klebsiella pneumoniae strain KP86_L3_06.23_ST147_NDM14 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137362
# unnamed3 Klebsiella pneumoniae strain KP10_L3_11.22_ST147 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137421
# unnamed3 Klebsiella pneumoniae strain KP81_L15_03.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137370
# unnamed3 Klebsiella pneumoniae strain KP99_L14_14.23_ST147_NDM5_OXA48 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP137354
# unnamed3 Haloprofundus halobius strain SEDH52 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP083669
# unnamed3 Escherichia coli strain CX16 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081753
# unnamed3 Escherichia coli strain CX11 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081734
# unnamed3 Escherichia coli strain CX19 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081760
# unnamed3 Escherichia coli strain CX14 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081741
# unnamed3 Escherichia coli strain CX06 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081799
# unnamed3 Escherichia coli strain CX20 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081809
# unnamed3 Tolypothrix sp. PCC 7601 plasmid unnamed3, complete sequence
# The dataset does not contain all the values
# unnamed3 Streptococcus pyogenes strain FDAARGOS_668 plasmid unnamed3
# unnamed3 Paracoccus yeei strain FDAARGOS_643 plasmid unnamed3, complete sequence
# The dataset does not contain all the values
# unnamed3 Klebsiella pneumoniae strain KP10_L3_11.22_ST147 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137421
# unnamed3 Klebsiella pneumoniae strain KP119_WM3_21.23_ST147_NDM1 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137398
# unnamed3 Klebsiella pneumoniae strain KP102_WM3_17.23_ST147_OXA181 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137410
# unnamed3 Klebsiella pneumoniae strain KP101_SE2_14.23_ST147_NDM5_OXA232 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137415
# unnamed3 Klebsiella pneumoniae strain KP39_L11_43.22_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137387
# unnamed3 Klebsiella pneumoniae strain KP124_L5_21.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137394
# unnamed3 Klebsiella pneumoniae strain KP51_L9_46.22_ST147_NDM1_OXA48 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137385
# unnamed3 Klebsiella pneumoniae strain KP82_L15_04.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137431
# unnamed3 Klebsiella pneumoniae strain KP88_L3_06.23_ST147_NDM14 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137430
# unnamed3 Klebsiella pneumoniae strain KP81_L15_03.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137370
# unnamed3 Klebsiella pneumoniae strain KP97_L17_12.23_ST147_NDM5 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137361
# unnamed3 Klebsiella pneumoniae strain KP86_L3_06.23_ST147_NDM14 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137362
# unnamed3 Klebsiella pneumoniae strain KP99_L14_14.23_ST147_NDM5_OXA48 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/CP137354
# unnamed3 Klebsiella pneumoniae strain BSIKPN-9 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP106915
# unnamed3 Klebsiella pneumoniae strain BSIKPN-11 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP106909
# unnamed3 Escherichia coli strain AH04 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081709
# unnamed3 Escherichia coli strain CX05 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081722
# unnamed3 Escherichia coli strain 0H18 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081769
# unnamed3 Escherichia coli strain 0H15 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081680
# unnamed3 Escherichia coli strain CX15 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081746
# unnamed3 Escherichia coli strain CX07 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081727
# unnamed3 Escherichia coli strain CX21 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081765
# unnamed3 Escherichia coli strain CX04 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081716
# unnamed3 Escherichia coli strain 0H25 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081693
# unnamed3 Escherichia coli strain AH02 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081704
# unnamed3 Escherichia coli strain 0H23 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081687
# unnamed3 Escherichia coli strain 0H24 plasmid unnamed3, complete sequence
# DataFrame made for unnamed3 at /content/unnamed3/NZ_CP081777
# ...
# unnamed Escherichia coli strain 0H26 plasmid unnamed 4, complete sequence
# The dataset does not contain all the values
# unnamed Escherichia coli strain 0H26 plasmid unnamed 3, complete sequence
# DataFrame made for unnamed 3 at /content/unnamed/NZ_CP081785
# unnamed Escherichia coli strain 0H26 plasmid unnamed 1, complete sequence
# DataFrame made for unnamed 1 at /content/unnamed/NZ_CP081783
# unnamed Bacillus sp. S3 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP039728
# unnamed Brevibacillus laterosporus strain Wq-1 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP136164
# unnamed Saccharomycopsis selenospora strain CBS 2563 plasmid unnamed
# unnamed Escherichia coli strain IY-BUK plasmid NDM family subclass B1 metallo-beta-lactamase (blaNDM) gene, partial cds
# unnamed Nosocomiicoccus massiliensis strain UMB0959 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP136965
# unnamed Streptococcus pasteurianus strain WUSP082 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP136944
# unnamed Bacillus cereus strain DP052 plasmid unnamed-6, whole genome shotgun sequence
# unnamed Bacillus cereus strain DP052 plasmid unnamed-3, whole genome shotgun sequence
# unnamed Klebsiella sp. w6 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP136908
# unnamed Serratia sp. UGAL515B_01 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP109900
# unnamed Staphylococcus aureus strain JDFM SA01 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP032822
# unnamed Shewanella algae strain VGH117 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP032414
# unnamed Aeromonas veronii strain jsyz553301 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP106829
# unnamed Klebsiella michiganensis strain K5-3 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP106839
# unnamed Erwinia pyrifoliae strain CP201264 plasmid unnamed, whole genome shotgun sequence
# unnamed Legionella longbeachae strain FDAARGOS_1481 plasmid unnamed
# unnamed Legionella pneumophila strain FDAARGOS_1482 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP082849
# unnamed Glutamicibacter nicotianae strain ZM05 plasmid unnamed
# unnamed Defluviicoccus vanus strain Ben 114 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP053924
# unnamed Salmonella enterica subsp. enterica serovar Derby strain SA1982 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_MT513102
# unnamed Vibrio paracholerae strain SIO plasmid unnamed, complete sequence
# The dataset does not contain all the values
# unnamed Pseudarthrobacter sp. Fe7 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP099978
# unnamed Lasiosphaeria miniovina strain SMH2392-1A chromosome Unknown B0T26scaffold_2, whole genome shotgun sequence
# unnamed Streptococcus pasteurianus strain WUSP082 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP136944
# unnamed Klebsiella sp. w6 plasmid unnamed, complete sequence
# The dataset does not contain all the values
# unnamed Sphingobium sp. SCG-1 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP026373
# unnamed Streptococcus equi subsp. equi strain XJ5012 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP134539
# unnamed Pyramidobacter sp. YE332 plasmid unnamed
# unnamed Serratia sp. UGAL515B_01 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP109900
# unnamed Microbacterium sp. NIBRBAC000506063 plasmid unnamed, complete sequence
# The dataset does not contain all the values
# unnamed Pyramidobacter sp. YE332 plasmid unnamed
# unnamed Staphylococcus aureus subsp. aureus 55/2053 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NC_022126
# unnamed Streptococcus equi subsp. equi strain XJ5012 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/CP134539
# unnamed Bradyrhizobium sp. BWA-3-5 plasmid unnamed
# unnamed Saccharomycopsis fibuligera strain CGMCC2.0968 plasmid unnamed
# unnamed Saccharomycopsis fibuligera strain CBS 329.83 plasmid unnamed
# unnamed Saccharomycopsis crataegensis strain NRRL YB-502 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/OR576209
# unnamed Riemerella anatipestifer strain 20200501E2-1 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP081932
# unnamed Riemerella anatipestifer strain 20190213Y1-1 plasmid unnamed, complete sequence
# DataFrame made for unnamed at /content/unnamed/NZ_CP081930
# Query running for p4_M47_H.defensa. (44/100)
# Folder made for p4_M47_Hdefensa
# p4_M47_H.defensa Candidatus Hamiltonella defensa strain MI47 plasmid p4_M47_H.defensa, complete sequence
# DataFrame made for p4_M47_H.defensa at /content/p4_M47_Hdefensa/NZ_CP022936
# p4_M47_H.defensa Candidatus Hamiltonella defensa strain MI47 plasmid p4_M47_H.defensa, complete sequence
# DataFrame made for p4_M47_H.defensa at /content/p4_M47_Hdefensa/CP022936
# Query running for p2_M47_H.defensa. (45/100)
# Folder made for p2_M47_Hdefensa
# p2_M47_H.defensa Candidatus Hamiltonella defensa strain MI47 plasmid p2_M47_H.defensa, complete sequence
# DataFrame made for p2_M47_H.defensa at /content/p2_M47_Hdefensa/NZ_CP022934
# p2_M47_H.defensa Candidatus Hamiltonella defensa strain MI47 plasmid p2_M47_H.defensa, complete sequence
# DataFrame made for p2_M47_H.defensa at /content/p2_M47_Hdefensa/CP022934
# Query running for p1107-IncFIB. (46/100)
# Folder made for p1107-IncFIB
# Query running for p1079-NDM. (47/100)
# Folder made for p1079-NDM
# p1079-NDM Escherichia coli strain 1079 plasmid p1079-NDM, complete sequence
# DataFrame made for p1079-NDM at /content/p1079-NDM/NZ_MG825384
# p1079-NDM Escherichia coli strain 1079 plasmid p1079-NDM, complete sequence
# DataFrame made for p1079-NDM at /content/p1079-NDM/MG825384
# Query running for p1079-IncFIB-N. (48/100)
# Folder made for p1079-IncFIB-N
# p1079-IncFIB-N Escherichia coli strain 1079 plasmid p1079-IncFIB-N, complete sequence
# DataFrame made for p1079-IncFIB-N at /content/p1079-IncFIB-N/NZ_MG825383
# p1079-IncFIB-N Escherichia coli strain 1079 plasmid p1079-IncFIB-N, complete sequence
# DataFrame made for p1079-IncFIB-N at /content/p1079-IncFIB-N/MG825383
# Query running for p977-NDM. (49/100)
# Folder made for p977-NDM
# p977-NDM Escherichia coli strain 977 plasmid p977-NDM, complete sequence
# DataFrame made for p977-NDM at /content/p977-NDM/NZ_MG825382
# p977-NDM Escherichia coli strain 977 plasmid p977-NDM, complete sequence
# DataFrame made for p977-NDM at /content/p977-NDM/MG825382
# Query running for p1108-MCR. (50/100)
# Folder made for p1108-MCR
# p1108-MCR Escherichia coli strain 1108 plasmid p1108-MCR, complete sequence
# DataFrame made for p1108-MCR at /content/p1108-MCR/NZ_MG825380
# p1108-MCR Escherichia coli strain 1108 plasmid p1108-MCR, complete sequence
# DataFrame made for p1108-MCR at /content/p1108-MCR/MG825380
# Query running for p1108-IncY. (51/100)
# Folder made for p1108-IncY
# p1108-IncY Escherichia coli strain 1108 plasmid p1108-IncY, complete sequence
# The dataset does not contain all the values
# p1108-IncY Escherichia coli strain 1108 plasmid p1108-IncY, complete sequence
# The dataset does not contain all the values
# Query running for p1108-IncFIB. (52/100)
# Folder made for p1108-IncFIB
# p1108-IncFIB Escherichia coli strain 1108 plasmid p1108-IncFIB, complete sequence
# DataFrame made for p1108-IncFIB at /content/p1108-IncFIB/NZ_MG825378
# p1108-IncFIB Escherichia coli strain 1108 plasmid p1108-IncFIB, complete sequence
# DataFrame made for p1108-IncFIB at /content/p1108-IncFIB/MG825378
# Query running for p1108-NDM. (53/100)
# Folder made for p1108-NDM
# p1108-NDM Escherichia coli strain EC1108 plasmid p1108-NDM_Vir, complete sequence
# DataFrame made for p1108-NDM_Vir at /content/p1108-NDM/NZ_OL763373
# p1108-NDM Escherichia coli strain 1108 plasmid p1108-NDM, complete sequence
# DataFrame made for p1108-NDM at /content/p1108-NDM/NZ_MG825381
# p1108-NDM Escherichia coli strain EC1108 plasmid p1108-NDM_Vir, complete sequence
# DataFrame made for p1108-NDM_Vir at /content/p1108-NDM/OL763373
# p1108-NDM Escherichia coli strain 1108 plasmid p1108-NDM, complete sequence
# DataFrame made for p1108-NDM at /content/p1108-NDM/MG825381
# Query running for p1108-emrB. (54/100)
# Folder made for p1108-emrB
# p1108-emrB Escherichia coli strain 1108 plasmid p1108-emrB, complete sequence
# DataFrame made for p1108-emrB at /content/p1108-emrB/NZ_MG825377
# p1108-emrB Escherichia coli strain 1108 plasmid p1108-emrB, complete sequence
# DataFrame made for p1108-emrB at /content/p1108-emrB/MG825377
# Query running for p1108-CMY2. (55/100)
# Folder made for p1108-CMY2
# p1108-CMY2 Escherichia coli strain 1108 plasmid p1108-CMY2, complete sequence
# DataFrame made for p1108-CMY2 at /content/p1108-CMY2/NZ_MG825376
# p1108-CMY2 Escherichia coli strain 1108 plasmid p1108-CMY2, complete sequence
# DataFrame made for p1108-CMY2 at /content/p1108-CMY2/MG825376
# Query running for p1106-NDM. (56/100)
# Folder made for p1106-NDM
# p1106-NDM Escherichia coli strain 1106 plasmid p1106-NDM, complete sequence
# DataFrame made for p1106-NDM at /content/p1106-NDM/NZ_MG825375
# p1106-NDM Escherichia coli strain 1106 plasmid p1106-NDM, complete sequence
# DataFrame made for p1106-NDM at /content/p1106-NDM/MG825375
# Query running for p1106-IncI2. (57/100)
# Folder made for p1106-IncI2
# p1106-IncI2 Escherichia coli strain 1106 plasmid p1106-IncI2, complete sequence
# DataFrame made for p1106-IncI2 at /content/p1106-IncI2/NZ_MG825374
# p1106-IncI2 Escherichia coli strain 1106 plasmid p1106-IncI2, complete sequence
# DataFrame made for p1106-IncI2 at /content/p1106-IncI2/MG825374
# Query running for p1106-IncHI2. (58/100)
# Folder made for p1106-IncHI2
# p1106-IncHI2 Escherichia coli strain 1106 plasmid p1106-IncHI2, complete sequence
# DataFrame made for p1106-IncHI2 at /content/p1106-IncHI2/NZ_MG825373
# p1106-IncHI2 Escherichia coli strain 1106 plasmid p1106-IncHI2, complete sequence
# DataFrame made for p1106-IncHI2 at /content/p1106-IncHI2/MG825373
# Query running for p1106-IncFIC. (59/100)
# Folder made for p1106-IncFIC
# Query running for p1106-IncB. (60/100)
# Folder made for p1106-IncB
# Query running for p974-NDM. (61/100)
# Folder made for p974-NDM
# p974-NDM Escherichia coli strain 974 plasmid p974-NDM, complete sequence
# DataFrame made for p974-NDM at /content/p974-NDM/NZ_MG825370
# p974-NDM Escherichia coli strain 974 plasmid p974-NDM, complete sequence
# DataFrame made for p974-NDM at /content/p974-NDM/MG825370
# Query running for p974-MCR. (62/100)
# Folder made for p974-MCR
# p974-MCR Escherichia coli strain 974 plasmid p974-MCR, complete sequence
# DataFrame made for p974-MCR at /content/p974-MCR/NZ_MG825369
# p974-MCR Escherichia coli strain 974 plasmid p974-MCR, complete sequence
# DataFrame made for p974-MCR at /content/p974-MCR/MG825369
# Query running for p787-NDM. (63/100)
# Folder made for p787-NDM
# p787-NDM Escherichia coli strain 787 plasmid p787-NDM, complete sequence
# DataFrame made for p787-NDM at /content/p787-NDM/NZ_MG825368
# p787-NDM Escherichia coli strain 787 plasmid p787-NDM, complete sequence
# DataFrame made for p787-NDM at /content/p787-NDM/MG825368
# Query running for p787-MCR. (64/100)
# Folder made for p787-MCR
# p787-MCR Escherichia coli strain 787 plasmid p787-MCR, complete sequence
# DataFrame made for p787-MCR at /content/p787-MCR/NZ_MG825367
# p787-MCR Escherichia coli strain 787 plasmid p787-MCR, complete sequence
# DataFrame made for p787-MCR at /content/p787-MCR/MG825367
# Query running for unnamed3. (65/100)
# Folder 'unnamed3' already exists.
# Folder made for unnamed3
# unnamed3 Priestia megaterium strain EA208 plasmid unnamed3, complete sequence
# The dataset does not contain all the values
# unnamed3 Staphylococcus epidermidis strain NBRC 113846 plasmid unnamed3, complete sequence
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-81fdca259748> in <cell line: 6>()
#      11     email_id = each_plasmid + '@gmail.com'
#      12     print(f"Query running for {each_plasmid}. ({j+1}/{len(each_batch)})")
# ---> 13     plasmid_data(each_plasmid,email_id)
#      14     j += 1
#      15   i += 1
#
# <ipython-input-4-6b4ba679ac3a> in plasmid_data(plasmid_name_1, plasmid_email_id)
#     110           dataframe = pd.DataFrame(plasmid_data)
#     111           # Saving the dataframe
# --> 112           dataframe.to_excel(f'{path}/{accession[0]}_{plasmid_name[0]}_data.xlsx', index = False)
#     113           print(f"DataFrame made for {plasmid_name[0]} at {path}/{accession[0]}")
#     114           dataframe.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2372             inf_rep=inf_rep,
#    2373         )
# -> 2374         formatter.write(
#    2375             excel_writer,
#    2376             sheet_name=sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     942             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944             writer = ExcelWriter(  # type: ignore[abstract]
#     945                 writer, engine=engine, storage_options=storage_options
#     946             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      58         engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      59
# ---> 60         super().__init__(
#      61             path,
#      62             mode=mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1311         )
#    1312         if not isinstance(path, ExcelWriter):
# -> 1313             self._handles = get_handle(
#    1314                 path, mode, storage_options=storage_options, is_text=False
#    1315             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732     # Only for write methods
#     733     if "r" not in mode and is_path:
# --> 734         check_parent_directory(str(handle))
#     735
#     736     if compression:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     595     parent = Path(path).parent
#     596     if not parent.is_dir():
# --> 597         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     598
#     599
#
# OSError: Cannot save file into a non-existent directory: 'None'

# %%
# By previous PLSDB data we were getting many errors so we made a new dataset (which we see above)

# This list of Plasmids contain many items that do not give us any result upon searching. (Ex- p1249-D-T,p17829f).
# Some don't have "complete sequence" but complete cds (Ex- t-ST4).
# Some have "complete genome" and not complete sequence in their description. (Ex- p05-9280TC1).
# There are some other issues as well

# So for now, we will make a folder if we get empty desired result i.e- (have plasmid name and "complete sequence" meantioned in their description)
# and after traversing through all the plasmids we will delete the folders that are empty.

test_plasmids = plasmids[258:270]

for i in range(len(test_plasmids)):
  each_plasmid = str(test_plasmids[i])
  email_id = each_plasmid + '@gmail.com'
  print(f"Query running for {each_plasmid}. ({i}/{len(test_plasmids)})")
  plasmid_data(each_plasmid,email_id)
# Out:
# Query running for 38.27. (0/12)
# Folder '3827' already exists.
# Folder made for 3827
# ['1960491938', '1960491937', '1960491936', '1960491935', '1960491934', '1960491933', '1960491932', '1960491931', '1960491930', '1960491929', '1960491928', '1960491927', '1960491926', '1960491925', '1960491924', '1960491923', '1960491922', '1960491921', '1960491920', '1960491919', '1960491918', '1960491917', '1960491916', '1960491915', '1960491914', '1960491913', '1960491912', '1960491911', '1960491910', '1960491909', '1960491908', '1960491907', '1960491906', '1960491905', '1960491904', '1960491903', '1960491902', '1960491901', '1960491900', '1960491899', '1960491898', '1960491897', '1960491896', '1960491895', '1960491894', '1960491893', '1960491892', '1960491891', '1960491890', '1960491889', '1960491888', '1960491887', '1960491886', '1960491885', '1960491884', '1960491883', '1960491882', '1960491881', '1960491880', '1960491879', '1960491878', '1960491877', '1960491876', '1960491875', '1960491874', '1960491873', '1960491872', '1960491871', '1960491870', '1960491869', '1960491868', '1960491867', '1960491866', '1960491865', '1960491864', '1960491863', '1960491862', '1960491861', '1960491860', '1960491859', '1960491858', '1960491857', '1960491856', '1960491855', '1960491854', '1960491853', '1960491852', '1960491851', '1960491850', '1960491849', '1960491848', '1960491847', '1960491846', '1960491845', '1960491844', '1960491843', '1960491842', '1960491841', '1960491840', '1960491839']
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-42-6adc0394d284> in <cell line: 11>()
#      13   email_id = each_plasmid + '@gmail.com'
#      14   print(f"Query running for {each_plasmid}. ({i}/{len(test_plasmids)})")
# ---> 15   plasmid_data(each_plasmid,email_id)
#      16
#      17
#
# <ipython-input-32-e97629b7112c> in plasmid_data(plasmid_name, plasmid_email_id)
#      33
#      34     # Extracting the genbank record for the id
# ---> 35     genbank_record = Entrez.efetch(db = 'nucleotide', id = records, rettype = 'gb', retmode = 'text')
#      36     # Reading the record
#      37     gb_record = SeqIO.read(genbank_record, 'genbank')
#
# /usr/local/lib/python3.10/dist-packages/Bio/Entrez/__init__.py in efetch(db, **keywords)
#     194     variables.update(keywords)
#     195     request = _build_request(cgi, variables)
# --> 196     return _open(request)
#     197
#     198
#
# /usr/local/lib/python3.10/dist-packages/Bio/Entrez/__init__.py in _open(request)
#     592     for i in range(max_tries):
#     593         try:
# --> 594             handle = urlopen(request)
#     595         except HTTPError as exception:
#     596             # Reraise if the final try fails
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request
