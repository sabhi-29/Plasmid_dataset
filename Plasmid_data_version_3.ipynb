# %%
# Attempting the new approach
# Importing neccesary libraries and function files

import os
import subprocess
import numpy as np
import pandas as pd
from Bio import Entrez, SeqIO
from urllib.request import urlretrieve
import requests
from colorama import Fore
from bs4 import BeautifulSoup
import time
import random
import scrapper
import plasmid_data_maker
import plasmid_list
import credentials
import abricate_plasmid

# %%
plasmids = plasmid_list.get_data()
print(len(plasmids))
# Out:
# 10321
# /home/ashar58/anaconda3/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1219: BiopythonParserWarning: Premature end of file in sequence data
#   warnings.warn(
# /home/ashar58/anaconda3/lib/python3.11/site-packages/Bio/GenBank/__init__.py:1377: BiopythonParserWarning: Expected sequence length 43088, found 16740 (LIZD01000039.1).
#   warnings.warn(

# %%
# # let's test out our progress so far - Testing for pP14_c

# plasmid_test = "pP14_c"

# name, email_id = credentials.query(plasmid_test)
# plasmid_data_maker.plasmid_data_improved(name, email_id, {})

# %%
# Testing for pSYM1, for now we keep the filter pass dictionary empty

# Our program is working perfectly
# Ask if anything needs to be added before running the loop for all plasmids in the list

# plasmid_test = "pSYM1"
# name, email_id = credentials.query(plasmid_test)
# folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, {})
# folder_dir = os.listdir(folder_path)

# if len(folder_dir) == 0:
#     print("No hits cleared both filters, deleting the directory created.")
#     os.remove(folder_dir)
# else:
#     print(f"Some hits found, see the directory {folder_path}")

# %%
# plasmid_test = "pWBG707"
# name, email_id = credentials.query(plasmid_test)
# folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, {})
# folder_dir = os.listdir(folder_path)

# if len(folder_dir) == 0:
#     print("No hits cleared both filters, deleting the directory created.")
#     os.remove(folder_dir)
# else:
#     print(f"Some hits found, see the directory {folder_path}")

# %%
### DEBUGGING CELL

plasmid_test = "pBM700"
name, email_id = credentials.query(plasmid_test)
folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, {})
# if no hits obtained we skip the query
if folder_path == None:
    print("No hits found")
else:
    folder_dir = os.listdir(folder_path)
    print(folder_path)
    if len(folder_dir) == 0:
        print("No hits cleared both filters, deleting the directory created.")
        os.remove(folder_dir)
    else:
        print(f"Some hits found, see the directory {folder_path}")

# %%
# Running the code now for all the plasmids in the list
successful_plasmid_hits = {}
i = 1
total = len(plasmids)
for each_plasmid in plasmids:
    print('-------------------------------------------------------------------------------------------------')
    print(f"Currently processing {i}/{total} plasmids.........")
    name, email_id = credentials.query(each_plasmid)
    folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, successful_plasmid_hits)
    if folder_path == None:
        print(f"No hits found for the plasmid: {each_plasmid}")
        print()
        print('-------------------------------------------------------------------------------------------------')
        i += 1
    else:
        folder_dir = os.listdir(folder_path)
        if len(folder_dir) == 0:
            print("No hits cleared both filters, deleting the directory created.")
            print()
            print('-------------------------------------------------------------------------------------------------')
            os.remove(folder_dir)
            i += 1
        else:
            print(f"Some hits found, see the directory {folder_path}")
            print()
            print('-------------------------------------------------------------------------------------------------')
            i += 1
# Out:
# -------------------------------------------------------------------------------------------------
# Currently processing 1/10321 plasmids.........
# Folder made for pRT801 as pRT801
# Pausing for 4 seconds...
# Resuming normal execution.
# Current hit: pRT801 :- Escherichia coli strain DH10B plasmid pRT801, complete sequence
# The hit MH192349 does not carry a pubmed id....... SKIPPING!
# No hits found for the plasmid: pRT801
#
# -------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------
# Currently processing 2/10321 plasmids.........
# Folder made for pFW213 as pFW213
# Pausing for 4 seconds...
# Resuming normal execution.
# Current hit: pFW213 :- Streptococcus parasanguinis plasmid pFW213, complete sequence
# The hit NC_012642 does not carry a pubmed id....... SKIPPING!
# Pausing for 3 seconds...
# Resuming normal execution.
# ...

# %%
# Running the code now for all the plasmids in the list
successful_plasmid_hits = {}
i = 348
total = len(plasmids)
for each_plasmid in plasmids[347:]:
    print('-------------------------------------------------------------------------------------------------')
    print(f"Currently processing {i}/{total} plasmids.........")
    name, email_id = credentials.query(each_plasmid)
    folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, successful_plasmid_hits)
    if folder_path == None:
        print(f"No hits found for the plasmid: {each_plasmid}")
        print()
        print('-------------------------------------------------------------------------------------------------')
        i += 1
    else:
        folder_dir = os.listdir(folder_path)
        if len(folder_dir) == 0:
            print("No hits cleared both filters, deleting the directory created.")
            print()
            print('-------------------------------------------------------------------------------------------------')
            os.remove(folder_dir)
            i += 1
        else:
            print(f"Some hits found, see the directory {folder_path}")
            print()
            print('-------------------------------------------------------------------------------------------------')
            i += 1
# Out:
# -------------------------------------------------------------------------------------------------
# Currently processing 348/10321 plasmids.........
# Folder made for pRetKim5c as pRetKim5c
# Pausing for 5 seconds...
# Resuming normal execution.
# Current hit: pRetKim5c :- Rhizobium sp. Kim5 plasmid pRetKim5c, complete sequence
# The hit NZ_CP021127 does not carry a pubmed id....... SKIPPING!
# Pausing for 5 seconds...
# Resuming normal execution.
# Current hit: pRetKim5c :- Rhizobium sp. Kim5 plasmid pRetKim5c, complete sequence
# The hit CP021127 does not carry a pubmed id....... SKIPPING!
# No hits found for the plasmid: pRetKim5c
#
# -------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------
# Currently processing 349/10321 plasmids.........
# Folder made for pLME10 as pLME10
# No hits found for the plasmid: pLME10
#
# ...

# %%
# Running the code now for all the plasmids in the list
successful_plasmid_hits = {}
i = 456
total = len(plasmids)
for each_plasmid in plasmids[455:]:
    print('-------------------------------------------------------------------------------------------------')
    print(f"Currently processing {i}/{total} plasmids.........")
    name, email_id = credentials.query(each_plasmid)
    folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, successful_plasmid_hits)
    if folder_path == None:
        print(f"No hits found for the plasmid: {each_plasmid}")
        print()
        print('-------------------------------------------------------------------------------------------------')
        i += 1
    else:
        folder_dir = os.listdir(folder_path)
        if len(folder_dir) == 0:
            print("No hits cleared both filters, deleting the directory created.")
            print()
            print('-------------------------------------------------------------------------------------------------')
            os.remove(folder_dir)
            i += 1
        else:
            print(f"Some hits found, see the directory {folder_path}")
            print()
            print('-------------------------------------------------------------------------------------------------')
            i += 1
# Out:
# -------------------------------------------------------------------------------------------------
# Currently processing 456/10321 plasmids.........
# Folder made for p2PIR00532 as p2PIR00532
# Pausing for 4 seconds...
# Resuming normal execution.
# Current hit: p2PIR00532 :- Salmonella enterica subsp. enterica serovar Enteritidis strain PIR00532 plasmid p2PIR00532, complete sequence
# Using nucl database plasmidfinder:  474 sequences -  2023-Dec-3
# Processing: /gpfs/fs1/home/ashar58/anaconda3/bin/p2PIR00532/NZ_CP025558_p2PIR00532.fa
# Found 1 genes in /gpfs/fs1/home/ashar58/anaconda3/bin/p2PIR00532/NZ_CP025558_p2PIR00532.fa
# Tip: you can use the --summary option to combine reports in a presence/absence matrix.
# Done.
# Using nucl database ncbi:  6739 sequences -  2023-Dec-3
# Processing: /gpfs/fs1/home/ashar58/anaconda3/bin/p2PIR00532/NZ_CP025558_p2PIR00532.fa
# Found 0 genes in /gpfs/fs1/home/ashar58/anaconda3/bin/p2PIR00532/NZ_CP025558_p2PIR00532.fa
# ...

# %%
# Running the code now for all the plasmids in the list
i = 1459
total = len(plasmids)
for each_plasmid in plasmids[1458:]:
    print('-------------------------------------------------------------------------------------------------')
    print(f"Currently processing {i}/{total} plasmids.........")
    name, email_id = credentials.query(each_plasmid)
    folder_path = plasmid_data_maker.plasmid_data_improved(name, email_id, successful_plasmid_hits)
    if folder_path == None:
        print(f"No hits found for the plasmid: {each_plasmid}")
        print()
        print('-------------------------------------------------------------------------------------------------')
        i += 1
    else:
        folder_dir = os.listdir(folder_path)
        if len(folder_dir) == 0:
            print("No hits cleared both filters, deleting the directory created.")
            print()
            print('-------------------------------------------------------------------------------------------------')
            os.remove(folder_dir)
            i += 1
        else:
            print(f"Some hits found, see the directory {folder_path}")
            print()
            print('-------------------------------------------------------------------------------------------------')
            i += 1
# Out:
# -------------------------------------------------------------------------------------------------
# Currently processing 1459/10321 plasmids.........
# Folder made for pKPC_CAV1193 as pKPC_CAV1193
# Pausing for 5 seconds...
# Resuming normal execution.
# Current hit: pKPC_CAV1193 :- Klebsiella pneumoniae strain CAV1193 plasmid pKPC_CAV1193, complete sequence
# Using nucl database plasmidfinder:  474 sequences -  2023-Dec-3
# Processing: /gpfs/fs1/home/ashar58/anaconda3/bin/pKPC_CAV1193/NZ_CP013325_pKPC_CAV1193.fa
# Found 1 genes in /gpfs/fs1/home/ashar58/anaconda3/bin/pKPC_CAV1193/NZ_CP013325_pKPC_CAV1193.fa
# Tip: remember that abricate is unable to find AMR-mediated SNPs.
# Done.
# Using nucl database ncbi:  6739 sequences -  2023-Dec-3
# Processing: /gpfs/fs1/home/ashar58/anaconda3/bin/pKPC_CAV1193/NZ_CP013325_pKPC_CAV1193.fa
# Found 2 genes in /gpfs/fs1/home/ashar58/anaconda3/bin/pKPC_CAV1193/NZ_CP013325_pKPC_CAV1193.fa
# ...

# %%
import dill
dill.dump_session('notebook_env.db')

# %%
plasmids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plasmids
#
# NameError: name 'plasmids' is not defined
